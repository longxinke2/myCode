# %% [markdown]
# # 模块导入

# %%
#1.导入ppt库
import pptx#调用的总的ppt的库，在进行安装的时候需要输入python-pptx
from pptx import Presentation#创造一个ppt对象
from pptx import util #设置幻灯片的大小
from pptx.enum.shapes import MSO_SHAPE #添加形状
from pptx.dml.color import RGBColor #颜色
from pptx.enum.dml import MSO_THEME_COLOR #形状的颜色
from pptx.enum.text import MSO_ANCHOR, MSO_AUTO_SIZE #文本框（或者说形状的格式设置）
from pptx.enum.text import PP_ALIGN#文本框里面，对于段落水平对齐的格式设置
from pyecharts.globals import CurrentConfig, OnlineHostType
CurrentConfig.ONLINE_HOST = OnlineHostType.NOTEBOOK_HOST


#2.导入数据处理模组
import pymysql
import psycopg2
import pandas as pd
from decimal import Decimal#保证比例呈现两位小数

#3.导入图像模组
# import echarts
from pyecharts.charts import Bar,Line,PictorialBar,Map,Pie,Sankey,Grid,Gauge,Radar,WordCloud,Liquid
from pyecharts import options as opts
from pyecharts.render import make_snapshot
from snapshot_selenium import snapshot
from pyecharts.commons.utils import JsCode
from pyecharts.components import Image
from pyecharts.options import ComponentTitleOpts
import seaborn as sns
import matplotlib.pyplot as plt
from pyecharts.charts import Liquid

from pyecharts.globals import CurrentConfig, OnlineHostType
CurrentConfig.ONLINE_HOST = OnlineHostType.NOTEBOOK_HOST

# %% [markdown]
# # 变量声明

# %%
#变量声明
bynd='2022'
xxmc='湖南高速铁路职业技术学院'
# xxmc='郴州职业技术学院'

# pic_path="C:/Users/Administrator/Desktop/陕西师范大学微报告/"
# pic_path="X:/报告盘/01就业质量报告/☆☆2022年/其他省/太原师范学院/【4自动化】2022太原师范/微报告/"
# pic_path="X:/报告盘/01就业质量报告/☆☆2022年/湖南省/郴州职业技术学院/【3.自动化】2022郴州/郴州职院微报告/"
pic_path="X:/报告盘/01就业质量报告/☆☆2022年/湖南省/湖南高速铁路职业技术学院/自动化/微报告/"


#颜色设置-红色
# color_1 = '#C11925' #红色
# color_2 = '#70AD47' #绿色
# color_3 = '#FFC000' #黄色
# color_4 = '#F4748C' #粉色
# color_5 = '#DC94DC' #紫色
# color_6 ='#333333'#黑色
# color_7 ='#f6e7e8'#主配色1 10%透明度颜色
# color_8 ='#f0f5ec'#主配色2 10%透明度颜色
# color_9 ='#fdf7e9'#主配色3 10%透明度颜色

# color1=RGBColor(193,25,37)
# color2=RGBColor(112,173,71)
# color3=RGBColor(255,192,0)
# color4=RGBColor(244,116,140)
# color5=RGBColor(220,148,220)
# color6=RGBColor(51,51,51)
# color7=RGBColor(246,231,232)
# color8=RGBColor(240,245,236)
# color9=RGBColor(253,247,233)

# #颜色设置-蓝绿色
# color_1 = '#0F63A2' #红色
# color_4 = '#2E863A' #绿色
# color_2 = '#2E87B4' #黄色
# color_3 = '#4FA9C7' #粉色
# color_5 = '#36A93B' #紫色
# color_6 ='#333333'#黑色
# color_7 ='#e8edf3'#主配色1 10%透明度颜色  蓝
# color_9 ='#e9f2ea'#主配色2 10%透明度颜色  绿
# color_8 ='#ebf4f8'#主配色3 10%透明度颜色  蓝

# color1=RGBColor(15,99,162)
# color4=RGBColor(46,134,58)
# color2=RGBColor(46,135,180)
# color3=RGBColor(79,169,199)
# color5=RGBColor(54,169,59)
# color6=RGBColor(51,51,51)
# color7=RGBColor(232,237,243)
# color9=RGBColor(233,242,234)
# color8=RGBColor(235,244,248)

# # 蓝绿色-城南
# color_1 = '#0F63A2' #主配色
# color_2 = '#2E87B4' #主配色
# color_3 = '#4FA9C7' #主配色
# color_4 = '#2E863A' 
# color_5 = '#36A93B' 


#标准蓝
color_1='#1a6fac'#深蓝 
color_2='#2f97c3'#浅蓝 
color_3='#d87587'#粉色 
color_4='#f1aa40'#黄色 
color_5 = '#cedfed'  #超浅的蓝
color_6='#333333'#黑色
color_7 ='#E7F0F6'#主配色1 10%透明度颜色
color_8 ='#FEF6EB'#主配色2 10%透明度颜色
color_9 ='#FAF1F3'#主配色3 10%透明度颜色

color1=RGBColor(26,111,172)
color2=RGBColor(47,151,195)
color3=RGBColor(216,117,135)
color4=RGBColor(241,170,64)
color5=RGBColor(206,223,237)
color6=RGBColor(51,51,51)
color7=RGBColor(231,240,246)
color8=RGBColor(254,246,235)
color9=RGBColor(250,241,243)

# #郴州蓝
# color_1 = '#147BC5'
# color_2 = '#FBB03E'
# color_3 = '#00ABCB'
# color_4 = '#70BC96'
# color_5 = '#E3798D'
# color_6='#333333'#黑色
# color_7 = '#E7F2F9'
# color_8 = '#FFF7EC'
# color_9 = '#E5F7FA'


# color1=RGBColor(26,111,172)
# color2=RGBColor(47,151,195)
# color3=RGBColor(216,117,135)
# color4=RGBColor(241,170,64)
# color5=RGBColor(206,223,237)
# color6=RGBColor(51,51,51)
# color7=RGBColor(231,242,249)
# color8=RGBColor(255,247,236)
# color9=RGBColor(229,247,250)

# # 山西农大-绿色
# color_1 = '#20882C' #主配色
# color_2 = '#FFC000' #主配色
# color_3 = '#89C064' #主配色
# color_4 = '#64B42A' 
# color_5 = '#FED71A' 
# color_6='#333333'#黑色
# color_7 = '#E9F3EA'
# color_8 = '#FFF9E5'
# color_9 = '#EFF7EA'


# color1=RGBColor(32,136,44)
# color2=RGBColor(255,192,0)
# color3=RGBColor(137,192,100)
# color4=RGBColor(100,180,42)
# color5=RGBColor(254,215,26)
# color6=RGBColor(51,51,51)
# color7=RGBColor(233,243,234)
# color8=RGBColor(255,249,229)
# color9=RGBColor(239,247,234)

#红色渐变
# color_1 = '#942225' #主配色
# color_2 = '#bc4743' #主配色
# color_3 = '#e56b62' #主配色
# color_4 = '#ff8f84' 
# color_5 = '#f4afa4' 
# color_6='#333333'#黑色
# color_7 = '#F4E9E9'
# color_8 = '#F4E9E9'
# color_9 = '#F4E9E9'

# color1=RGBColor(148, 34, 37)
# color2=RGBColor(188, 71, 67)
# color3=RGBColor(229, 107, 98)
# color4=RGBColor(255, 143, 132)
# color5=RGBColor(244, 175, 164)
# color6=RGBColor(51,51,51)
# color7=RGBColor(244, 233, 233)
# color8=RGBColor(244, 233, 233)
# color9=RGBColor(244, 233, 233)


#XX绿
# color_1 = '#377780' #主配色
# color_2 = '#EB833F' #主配色
# color_3 = '#34A196' #主配色
# color_4 = '#6CB9B2' 
# color_5 = '#F7B975' 
# color_6='#333333'#黑色
# color_7 = '#EBF1F2'
# color_8 = '#FDF3EC'
# color_9 = '#EBF6F4'

# color1=RGBColor(55, 119, 128)
# color2=RGBColor(235, 131, 63)
# color3=RGBColor(52, 161, 150)
# color4=RGBColor(108, 185, 178)
# color5=RGBColor(247, 185, 117)
# color6=RGBColor(51,51,51)
# color7=RGBColor(235, 241, 242)
# color8=RGBColor(253, 243, 236)
# color9=RGBColor(235, 246, 244)



font_1 = '思源黑体 CN Semibold'   #最粗的标题字体
font_2 = '思源黑体 CN Medium'    #通常用于数据与标题
font_3 = '思源黑体 CN Regular' #通常用于内里正文

# %%
# color_1 = '#C81717' #主配色
# color_2 = '#E97171' #主配色
# color_3 = '#FFD68B' #主配色
# color_4 = '#F6A176' 
# color_5 = '#F8CBB2'

# %% [markdown]
# # 定义函数

# %%
def RGB_list_to_Hex(RGB):
    # RGB = rgb.split(',') # 将RGB格式划分开来
    color = '#'
    for i in RGB:
        num = int(i)
        # 将R、G、B分别转化为16进制拼接转换并大写 hex() 函数用于将10进制整数转换成16进制，以字符串形式表示
        color += str(hex(num))[-2:].replace('x', '0').upper()
    return color
# 16进制颜色格式颜色转换为RGB格式
def Hex_to_RGB(hex):
    r = int(hex[1:3], 16)
    g = int(hex[3:5], 16)
    b = int(hex[5:7], 16)
    rgb = str(r) + ',' + str(g) + ',' + str(b)
    return rgb, [r, g, b]
# 生成渐变色
def gradient_color(color_list, color_sum=700):
    color_center_count = len(color_list)
    # if color_center_count == 2:
    # color_center_count = 1
    color_sub_count = int(color_sum / (color_center_count - 1))
    color_index_start = 0
    color_map = []
    for color_index_end in range(1, color_center_count):
        color_rgb_start = Hex_to_RGB(color_list[color_index_start])[1]
        color_rgb_end = Hex_to_RGB(color_list[color_index_end])[1]
        r_step = (color_rgb_end[0] - color_rgb_start[0]) / color_sub_count
        g_step = (color_rgb_end[1] - color_rgb_start[1]) / color_sub_count
        b_step = (color_rgb_end[2] - color_rgb_start[2]) / color_sub_count
        # 生成中间渐变色
        now_color = color_rgb_start
        color_map.append(RGB_list_to_Hex(now_color))
    for color_index in range(1, color_sub_count):
        now_color = [now_color[0] + r_step, now_color[1] + g_step, now_color[2] + b_step]
        color_map.append(RGB_list_to_Hex(now_color))
        color_index_start = color_index_end
    return color_map
def get_lighter_color(*args):
    colors = gradient_color(args)
    sns.palplot(colors[::int(len(colors)/10)][:])
    return colors[::int(len(colors)/10)][:],plt.show()
def decimal(number):#保证比例固定两位小数
    out=str(Decimal(number*100).quantize(Decimal("0.00")))+'%'
    return out

# %% [markdown]
# # 连接数据库

# %%
#连接PostgreSQL数据库
conn_3 = psycopg2.connect(database="weyon", #数据库名
                        user="LTAI5tLAtRZDhcHSaW3mYJsx", #用户名
                        password="foaMQRl3Nr5KLccBi4f3vNIymQDN0Z", #用户密码
                        host="lightning.cn-shenzhen.maxcompute.aliyun.com", #主机
                        port="443") #端口信息

#连接dw_database数据库
conn=pymysql.connect(host = 'am-wz9el267w54i2r7ip131930o.ads.aliyuncs.com' # 连接名称，默认127.0.0.1
,user = 'yjy_user' # 用户名
,passwd='Yjy123456' # 密码
,port= 3306 # 端口，默认为3306
,db='dw_database'#数据库名称
,charset='utf8' # 字符编码
)

#连接warehouse数据库
conn_1=pymysql.connect(host = 'am-wz9el267w54i2r7ip131930o.ads.aliyuncs.com' # 连接名称，默认127.0.0.1
,user = 'yjy_user' # 用户名
,passwd='Yjy123456' # 密码
,port= 3306 # 端口，默认为3306
,db='warehouse'#数据库名称
,charset='utf8' # 字符编码
)

#连接yun-campusjob数据库
conn_2=pymysql.connect(host = 'am-wz9el267w54i2r7ip131930o.ads.aliyuncs.com' # 连接名称，默认127.0.0.1
,user = 'yjy_user' # 用户名
,passwd='Yjy123456' # 密码
,port= 3306 # 端口，默认为3306
,db='yun-campusjob'#数据库名称
,charset='utf8' # 字符编码
)

# %% [markdown]
# # 数据库取数

# %%
#派遣数据
sql_jy =f'''
    SELECT * FROM dw_s_employment_auto
    where xxmc = '{xxmc}' and substring(bynd,1,4) = '{bynd}'
    '''
data_pq = pd.read_sql(sql=sql_jy, con=conn)

# sql_hndy = f'''
#     SELECT * FROM dw_s_short_survey_hunan_province_auto 
#     where dy_xxmc = '{xxmc}'
#     '''
# df_hndy = pd.read_sql(sql=sql_hndy,con=conn) #取出湖南省调研数据

#毕业生调研数据
sql_dy = f'''
    SELECT * FROM dw_2022_s_short_survey_hunan_province_auto
    where dy_yxmc = '{xxmc}' 
     '''
data_dy = pd.read_sql(sql=sql_dy,con=conn)

#单位调研数据
sql_dw = f'''
    SELECT * FROM dw_2022_c_short_survey_hunan_province_auto
    where cdy_yxmc = '{xxmc}'
    '''
data_dwdy = pd.read_sql(sql=sql_dw,con=conn)
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python38\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\Administrator\AppData\Roaming\Python\Python38\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\Administrator\AppData\Roaming\Python\Python38\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
data_pq.tail(3)
# Out:
#        xxdm          xxmc  bynd      yx  zydm        zy    bj   xm  \
# 4850  13941  湖南高速铁路职业技术学院  2022  铁道建筑学院  None    建筑工程技术  None   全凯
# 4851  13941  湖南高速铁路职业技术学院  2022  铁道运输学院  None  铁道交通运营管理  None  宋春霞
# 4852  13941  湖南高速铁路职业技术学院  2022  铁道动力学院  None      铁道车辆  None  易琦瑛
#
#                 xh               sfzhm  ... dim_company_property  \
# 4850  201993413264  430422200111242114  ...
# 4851  201993414657  360702200011181927  ...
# 4852  201993412557  43110220020101101X  ...
#
#      dim_industry_category dim_scale dim_registered_capital dim_dwmc_province  \
# 4850
# 4851
# 4852
#
#      dim_dwmc_city     jylbfl       dwhy_c sjly xxmc_c
# 4850                签就业协议形式就业  交通运输、仓储和邮政业   国库   None
# 4851                 其他录用形式就业  交通运输、仓储和邮政业   国库   None
# 4852                 其他录用形式就业       批发和零售业   国库   None
#
# [3 rows x 81 columns]

# %%
data_dy.tail(3)
# Out:
#       dy_yxdm       dy_yxmc dy_yxszdqdm   dy_xx dy_xb dy_mz dy_jyknlb dy_kslb  \
# 4757  13941.0  湖南高速铁路职业技术学院    430400.0  铁道电信学院     男    汉族    家庭经济困难    城镇往届
# 4758  13941.0  湖南高速铁路职业技术学院    430400.0  铁道运输学院     女   土家族      非困难生    城镇应届
# 4759  13941.0  湖南高速铁路职业技术学院    430400.0  铁道运输学院     女   土家族      非困难生    城镇应届
#
#       dy_xl dy_xl_c  ... dy_rcpymyd dy_mxtjd dy_sfslb dy_jycyfwmyd  \
# 4757  专科毕业生   专科毕业生  ...          4        4     None            4
# 4758  专科毕业生   专科毕业生  ...          3        1     None            3
# 4759  专科毕业生   专科毕业生  ...          4        4     None            5
#
#      dy_new_jycypj_zdk dy_new_jycypj_xxtg dy_new_jycypj_jysx  \
# 4757                 5                  5                  4
# 4758                 3                  3                  3
# 4759                 5                  5                  5
#
#      dy_new_jycypj_knbf dy_new_jycypj_zcxc dy_new_jycypj_cyzx
# 4757                  5                  5                  5
# ...

# %%
data_dwdy.tail(3)
# Out:
#    cdy_nf cdy_ybid      cdy_yxmc         cdy_dwmc cdy_dwszd    cdy_dwgm  \
# 52   2022        1  湖南高速铁路职业技术学院       昆明铁路局曲靖车务段        西部  1000-4999人
# 53   2022        1  湖南高速铁路职业技术学院  台州市锐安硬质合金工具有限公司        长三    500-999人
# 54   2022        1  湖南高速铁路职业技术学院     悦洋设施管理服务有限公司        珠三  1000-4999人
#
#    cdy_dwxz       cdy_dwhy cdy_zpgmbh                 cdy_zpqd  ...  \
# 52     国有企业    交通运输、仓储和邮政业         持平                校园招聘会/双选会  ...
# 53  民（私）营企业            制造业         持平  校园招聘会/双选会;云平台线上招聘会;学生自荐  ...
# 54  外（合）资企业  居民服务、修理和其他服务业         持平  校园招聘会/双选会;在实习（见习）中选拔;内推  ...
#
#    cdy_byspj_kjyynl cdy_byspj_xxhqnl cdy_byspj_xtswnl cdy_fzql  \
# 52                4                5                5        4
# 53                3                3                3        3
# 54                5                5                5        4
#
#                       cdy_lxzpyy cdy_rcpymyd                 cdy_rcpyjy  \
# ...

# %% [markdown]
# # 取数&图片导出

# %% [markdown]
# ## 毕业生性别结构

# %%
#毕业生性别结构数据取数 并画图
bys_all_number=data_pq.count()['xxdm']#毕业生总人数

bys_nv_number,bys_nan_number=data_pq.groupby(['xb']).count()['xh']#女性毕业生、男性毕业生
bys_nv_ratio,bys_nan_ratio=data_pq.groupby(['xb']).count()['xh']/bys_all_number#女性毕业生比例、男性毕业生比例
if bys_nan_ratio>bys_nv_ratio:#根据人数多少确定前后
    bys_xb_former='男性'
    bys_xb_latter='女性'
else:
    bys_xb_former='女性'
    bys_xb_latter='男性'

bys_xb_zip=list(zip(['男生','女生'],[bys_nan_ratio,bys_nv_ratio]))
#毕业生圆环图
xb_Pie= (
    Pie()
    .add('',bys_xb_zip,radius=["80%", "50%"],
        label_line_opts=opts.PieLabelLineOpts(length=200,linestyle_opts=opts.LineStyleOpts(width=5)),
        label_opts=opts.LabelOpts(interval=0,
        font_size=45,
        position="outside",
        formatter='{d|{d}}'+"%",
        rich={
            "d": {"fontSize": 45, "lineHeight": 200, "fontFamily":font_3},
            }
        )
        )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="总人数\n",
                                  subtitle=f'{bys_all_number}人',
                                  pos_left="center",
                                  pos_bottom="40%",
                                  title_textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_1,color=color_1),
                                  subtitle_textstyle_opts=opts.TextStyleOpts(font_size = 60,font_family = font_2,color=color_1)
                                  ),
        legend_opts=opts.LegendOpts(is_show=True,
                                   pos_top='bottom',
                                   item_width=45,
                                   item_height=45,
                                   item_gap=200,
                                   textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=[color_1,color_3])
                                   )
                    )
    .set_colors([color_1,color_4])
)

xb_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1250px'))  #设置图形大小,高度:height,宽度:width
.add(xb_Pie, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,xb_Pie.render(), pic_path+'毕业生性别圆环.png',pixel_ratio = 5)
xb_Pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'http://localhost:8888/nbextensions/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8f045205dfaa442da82c72bc93917c9f" style="width:1250px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8f045205dfaa442da82c72bc93917c9f = echarts.init(
#                     document.getElementById('8f045205dfaa442da82c72bc93917c9f'), 'white', {renderer: 'canvas'});
#                 var option_8f045205dfaa442da82c72bc93917c9f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#1a6fac",
#         "#f1aa40"
#     ],
#     "series": [
#         {
#             "type": "pie",
# ...

# %% [markdown]
# ## 毕业生生源结构

# %%
#毕业生生源结构取数 画图
xxsf=data_pq["xxsf"][0]

bys_sf_number=data_pq.groupby(["sysf"]).count()["xh"].sort_values(ascending=False)#生源省份取数

bys_sn_number=bys_sf_number[f"{xxsf}"]#省内人数
bys_sn_ratio=bys_sn_number/bys_all_number

bys_sw_number=bys_sf_number.drop(f"{xxsf}")

bys_sw_fir_name,bys_sw_sec_name,bys_sw_thi_name=bys_sw_number.index[:3]#省外前三名字
bys_sw_fir_number,bys_sw_sec_number,bys_sw_thi_number=bys_sw_number[:3]#省外前三数量
bys_sw_fir_ratio,bys_sw_sec_ratio,bys_sw_thi_ratio=(bys_sw_number/bys_all_number)[:3]#省外前三比例

#中国地图
def picture_china_map(data,picture_name,color = get_lighter_color('#FFFFFF',color_1)[0]):#计算的排名，所以颜色需要倒置
    data_zip = [*zip(data.index.tolist(),data)]#构建省份和对应统计人数的列表,地图数据传入的指定格式
    for i in range(len(data_zip)):
        data_zip[i]=[data_zip[i][0],data_zip[i][1]]
        data_zip[i][1]=i+1
    color_new=color[::-1]
    max_ = data_zip[len(data_zip)-1][1]
    a= (
    Map()
    .add("",data_zip,"china",is_map_symbol_show = False,is_roam = True,#数据传入,地图类型设置:中国地图"china"
         itemstyle_opts=opts.ItemStyleOpts(border_color = '#FFFFFF')) #图形的描边颜色
    .set_global_opts(
         visualmap_opts=opts.VisualMapOpts(is_show=False,max_ = max_,min_=3,range_color = color_new,
                                          is_piecewise=True,
                                          pieces=[{'min': 0 , 'max':1, 'label':1, 'color':color_1},
                                                  {'min': 1 , 'max':2, 'label':2, 'color':color_2},
                                                  {'min': 2 , 'max':3, 'label':3, 'color':color_3},
                                                  {'min': 3 , 'max':4, 'label':4, 'color':color_4},
                                                  {'min': 4 , 'max':max_, 'label':5, 'color':color_7}
                                                 ]),
         legend_opts=opts.LegendOpts(is_show=True,
                                   pos_top='bottom',
                                   pos_left='center',
                                   item_width=10000,
                                   item_height=45,
                                   textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_6)
                                   )
                    )#颜色渐变设置
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
    return a.render_notebook()
picture_china_map(bys_sf_number,'生源结构地图')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'http://localhost:8888/nbextensions/assets/echarts.min', 'china':'http://localhost:8888/nbextensions/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="2fb15ae52c16431fa06b19ce04189e94" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_2fb15ae52c16431fa06b19ce04189e94 = echarts.init(
#                     document.getElementById('2fb15ae52c16431fa06b19ce04189e94'), 'white', {renderer: 'canvas'});
#                 var option_2fb15ae52c16431fa06b19ce04189e94 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-9c9a2cba73bf> in <module>
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
def picture_china_map(data, picture_name,color = get_lighter_color('#FFFFFF',color_1)[0]):#计算的排名，所以颜色需要倒置
    data_zip = [*zip(data.index.tolist())]#构建省份和对应统计人数的列表,地图数据传入的指定格式
    for i in range(len(data_zip)):
        data_zip[i]=[data_zip[i][0],i+1]
    color_new=color[::-1]
    max_ = data_zip[len(data_zip)-1][1]
    a= (
    Map()
    .add("",data_zip,"china",is_map_symbol_show = False,is_roam = True,#数据传入,地图类型设置:中国地图"china"
         itemstyle_opts=opts.ItemStyleOpts(border_color = '#FFFFFF')) #图形的描边颜色
    .set_global_opts(
         visualmap_opts=opts.VisualMapOpts(is_show=False,max_ = max_,min_=3,range_color = color_new,
                                          is_piecewise=True,
                                          pieces=[{'min': 0 , 'max':1, 'label':1, 'color':color_1},
                                                  {'min': 1 , 'max':2, 'label':2, 'color':color_2},
                                                  {'min': 2 , 'max':3, 'label':3, 'color':color_3},
                                                  {'min': 3 , 'max':4, 'label':4, 'color':color_4},
                                                  {'min': 4 , 'max':max_, 'label':5, 'color':color_7}
                                                 ]),
         legend_opts=opts.LegendOpts(is_show=True,
                                   pos_top='bottom',
                                   pos_left='center',
                                   item_width=10000,
                                   item_height=45,
                                   textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_6)
                                   )
                    )#颜色渐变设置
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
    return  make_snapshot(snapshot,a.render(), f'{ picture_name}.png',pixel_ratio = 5),a.render_notebook()
picture_china_map(bys_sf_number,'生源结构地图')

# %% [markdown]
# ## 毕业生毕业去向7个率

# %%
#毕业去向落实率取数 +画图
byqxls_ratio=data_pq.groupby(["lsbyqx"]).count()["xh"]['是']/bys_all_number#毕业去向落实率
xyhtjy_ratio=data_pq.groupby(["xyhtjy"]).count()["xh"]['是']/bys_all_number#协议和合同就业率
gnsx_ratio=(data_pq.groupby(["gnsx"]).count()["xh"]['是'])/bys_all_number#国内升学率
try:
    cgcj_ratio=(data_pq.groupby(["cgcj"]).count()["xh"]['是'])/bys_all_number
except:
    cgcj_ratio=0

jxsz_ratio=gnsx_ratio+cgcj_ratio #继续深造率
# jxsz_ratio=data_pq.groupby((["gnsx"]).count()["xh"]['是']+(["cgcj"]).count()["xh"]['是'])/bys_all_number#继续深造率
zzcy_ratio=data_pq.groupby(["cy"]).count()["xh"]['是']/bys_all_number#自主创业率
lhjy_ratio=data_pq.groupby(["lhjy"]).count()["xh"]['是']/bys_all_number#灵活就业率
try:
    zbjy_ratio=data_pq.groupby(["jylbfl"]).count()['xh']['暂不就业']/bys_all_number#暂不就业率
except:
    zbjy_ratio=0

try:   
    djy_ratio=data_pq.groupby(["jylbfl"]).count()["xh"]['待就业']/bys_all_number#待就业率
except:
    djy_ratio=0
    
    
byqx_zip=[decimal(byqxls_ratio),byqxls_ratio]
byqx_Liquid= (
    Liquid()
    .add(decimal(byqxls_ratio), byqx_zip, is_outline_show=False,color=[color_1],background_color=[color_7],label_opts=opts.LabelOpts(interval=0,
        font_size=60,position="inside",font_family=font_2)
        )
    .set_global_opts(title_opts=opts.TitleOpts(title="初次毕业去向落实率",
                                              pos_left="center",
                                              pos_bottom="15%",
                                              title_textstyle_opts=opts.TextStyleOpts(font_size = 30,font_family = font_3,color=color_1)
                                              )
                    )
)

byqx_Liquid= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(byqx_Liquid, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,byqx_Liquid.render(), pic_path+'毕业去向落实率水滴图.png',pixel_ratio = 5)

# %%
byqxls_ratio

# %%
data_pq.groupby(["cgcj"]).count()["xh"]

# %%
 djy_ratio

# %% [markdown]
# ## 就业单位主要特征

# %%
#就业单位主要特征取数

bys_dwhy_ratio=(data_pq.query("dwjy=='是'").groupby(["dwhy"]).count()["xh"]/data_pq.query("dwjy=='是'").count()["xh"]).sort_values(ascending=False)#单位行业
bys_dwxz_ratio=(data_pq.query("dwjy=='是'").groupby(["dwxz"]).count()["xh"]/data_pq.query("dwjy=='是'").count()["xh"]).sort_values(ascending=False)#单位性质
bys_zwlx_ratio=(data_pq.query("dwjy=='是'").groupby(["gzzwlb"]).count()["xh"]/data_pq.query("dwjy=='是'").count()["xh"]).sort_values(ascending=False)#职位类型

# %% [markdown]
# ## 重点战略地区

# %%
#重点战略地区
bys_cjjjd_ratio=data_pq.query("dwjy=='是'").count()['cjjjd']/data_pq.query("dwjy=='是'").count()['xh']#长江经济带
bys_ydyl_ratio=data_pq.query("dwjy=='是'").count()['ydyl']/data_pq.query("dwjy=='是'").count()['xh']#一带一路经济带
bys_csj_ratio=data_pq.query("dwjy=='是'").count()['csj']/data_pq.query("dwjy=='是'").count()['xh']#长江三角洲地区
bys_jjj_ratio=data_pq.query("dwjy=='是'").count()['jjj']/data_pq.query("dwjy=='是'").count()['xh']#京津冀地区
bys_yga_ratio=data_pq.query("dwjy=='是'").count()['ygadwq']/data_pq.query("dwjy=='是'").count()['xh']#粤港澳地区
bys_hhly_ratio=data_pq.query("dwjy=='是'").count()['hhly']/data_pq.query("dwjy=='是'").count()['xh']#黄河流域

#长江经济带
cjjjd_Pie= (
    Pie()
    .add('',[('',bys_cjjjd_ratio),('否',1-bys_cjjjd_ratio)],radius=["80%", "60%"])
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_1,color_7])
)

cjjjd_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(cjjjd_Pie, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,cjjjd_Pie.render(), pic_path+'长江经济带.png',pixel_ratio = 5)


#一带一路经济带
ydyl_Pie= (
    Pie()
    .add('',[('',bys_ydyl_ratio),('否',1-bys_ydyl_ratio)],radius=["80%", "60%"])
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_1,color_7])
)

ydyl_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(ydyl_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,ydyl_Pie.render(), pic_path+'一带一路经济带.png',pixel_ratio = 5)



#长江三角洲地区
csj_Pie= (
    Pie()
    .add('',[('',bys_csj_ratio),('否',1-bys_csj_ratio)],radius=["80%", "60%"])
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_1,color_7])
)

csj_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(csj_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,csj_Pie.render(), pic_path+'长江三角洲区域.png',pixel_ratio = 5)



#京津冀区域
jjj_Pie= (
    Pie()
    .add('',[('',bys_jjj_ratio),('否',1-bys_jjj_ratio)],radius=["80%", "60%"])
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_1,color_7])
)

jjj_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(jjj_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,jjj_Pie.render(), pic_path+'京津冀区域.png',pixel_ratio = 5)
#粤港澳大湾区
yga_Pie= (
    Pie()
    .add('',[('',bys_yga_ratio),('否',1-bys_yga_ratio)],radius=["80%", "60%"])
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_1,color_7])
)

yga_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(yga_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,yga_Pie.render(), pic_path+'粤港澳大湾区.png',pixel_ratio = 5)


#黄河流域
hhly_Pie= (
    Pie()
    .add('',[('',bys_hhly_ratio),('否',1-bys_hhly_ratio)],radius=["80%", "60%"])
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_1,color_7])
)

hhly_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(hhly_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,hhly_Pie.render(), pic_path+'黄河流域.png',pixel_ratio = 5)

# %% [markdown]
# ## 地域流向

# %%
#地域流向取数和画图
bys_dy_number=data_pq.query("dwjy=='是'").groupby(["sfmc"]).count()["xh"].sort_values(ascending=False)#省份取数

bys_dy_fir_name,bys_dy_sec_name,bys_dy_thi_name,bys_dy_for_name=bys_dy_number.index[:4]#省外前四名字
bys_dy_fir_number,bys_dy_sec_number,bys_dy_thi_number,bys_dy_for_number=bys_dy_number[:4]#省外前四数量
bys_dy_fir_ratio,bys_dy_sec_ratio,bys_dy_thi_ratio,bys_dy_for_ratio=(bys_dy_number/bys_dy_number.sum())[:4]#省外前四比例

#中国地图
def picture_china_map(data,picture_name):#计算的排名，所以颜色需要倒置
    data_zip = [*zip(data.index.tolist(),data)]#构建省份和对应统计人数的列表,地图数据传入的指定格式
    for i in range(len(data_zip)):
        data_zip[i]=[data_zip[i][0],data_zip[i][1]]
        data_zip[i][1]=i+1
    max_ = data_zip[len(data_zip)-1][1]
    a= (
    Map()
    .add("",data_zip,"china",is_map_symbol_show = False,is_roam = True,#数据传入,地图类型设置:中国地图"china"
         itemstyle_opts=opts.ItemStyleOpts(border_color = '#FFFFFF')) #图形的描边颜色
    .set_global_opts(
         visualmap_opts=opts.VisualMapOpts(is_show=False,max_ = max_,
                                          is_piecewise=True,
                                          pieces=[{'min': 0 , 'max':1, 'label':1, 'color':color_1},
                                                  {'min': 1 , 'max':2, 'label':2, 'color':color_2},
                                                  {'min': 2 , 'max':3, 'label':3, 'color':color_3},
                                                  {'min': 3 , 'max':4, 'label':4, 'color':color_4},
                                                  {'min': 4 , 'max':max_, 'label':5, 'color':color_7}
                                                 ]),
         legend_opts=opts.LegendOpts(is_show=False,
                                   pos_top='bottom',
                                   pos_left='center',
                                   item_width=10000,
                                   item_height=45,
                                   textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_6)
                                   )
                    )#颜色渐变设置
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
    return make_snapshot(snapshot,a.render(), pic_path+f'{picture_name}.png',pixel_ratio = 5),a.render_notebook()
picture_china_map(bys_dy_number,'地域流向图')

# %% [markdown]
# ## 省内城市流向top3

# %%
#省内城市流向top3
sn_data=data_pq[data_pq["sfmc"]==xxsf]
sn_cs_data=sn_data.query("dwjy=='是'").groupby(["sqmc"]).count()["xh"].sort_values(ascending=False)
sn_cs_fir_name,sn_cs_sec_name,sn_cs_thi_name=sn_cs_data.index[:3]#计算城市流向前三
sn_cs_fir_number,sn_cs_sec_number,sn_cs_thi_number=sn_cs_data[:3]
sn_cs_fir_ratio,sn_cs_sec_ratio,sn_cs_thi_ratio=(sn_cs_data/sn_cs_data.sum())[:3]



sn_cs1_zip=[decimal(sn_cs_fir_ratio),sn_cs_fir_ratio]#省内城市第一
if sn_cs_fir_ratio>0.5:
    color_now='#ffffff'
else:
    color_now=color_1
sn_cs1_Liquid= (
    Liquid()
    .add(decimal(sn_cs_fir_ratio), sn_cs1_zip,color=[color_1],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
        font_size=70,position="inside",color=color_now,font_family=font_2)
        )
    .set_global_opts(title_opts=opts.TitleOpts(title=sn_cs_fir_name,
                                              pos_left="center",
                                              pos_bottom="15%",
                                              title_textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_1)
                                              )
                    )
)

sn_cs1_Liquid= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(sn_cs1_Liquid, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,sn_cs1_Liquid.render(), pic_path+'省内城市流向1.png',pixel_ratio = 5)



sn_cs2_zip=[decimal(sn_cs_sec_ratio),sn_cs_sec_ratio]#省内城市第二
if sn_cs_sec_ratio>0.5:
    color_now='#ffffff'
else:
    color_now=color_4
sn_cs2_Liquid= (
    Liquid()
    .add(decimal(sn_cs_sec_ratio), sn_cs2_zip,color=[color_4],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
        font_size=70,position="inside",color=color_now,font_family=font_2)
        )
    .set_global_opts(title_opts=opts.TitleOpts(title=sn_cs_sec_name,
                                              pos_left="center",
                                              pos_bottom="15%",
                                              title_textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_4)
                                              )
                    )
)
sn_cs2_Liquid= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(sn_cs2_Liquid, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,sn_cs2_Liquid.render(), pic_path+'省内城市流向2.png',pixel_ratio = 5)



sn_cs3_zip=[decimal(sn_cs_thi_ratio),sn_cs_thi_ratio]#省内城市第三
if sn_cs_thi_ratio>0.5:
    color_now='#ffffff'
else:
    color_now=color_3
sn_cs3_Liquid= (
    Liquid()
    .add(decimal(sn_cs_thi_ratio), sn_cs3_zip,color=[color_3],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
        font_size=70,position="inside",color=color_now,font_family=font_2)
        )
    .set_global_opts(title_opts=opts.TitleOpts(title=sn_cs_thi_name,
                                              pos_left="center",
                                              pos_bottom="15%",
                                              title_textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_3),
                                              )
                    )
)

sn_cs3_Liquid= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(sn_cs3_Liquid, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,sn_cs3_Liquid.render(), pic_path+'省内城市流向3.png',pixel_ratio = 5)

# %%
# #市内区县流向top3（重庆市）
# sn_data=data_pq[data_pq["sqmc"]==xxsf]
# sn_cs_data=sn_data.query("dwjy=='是'").groupby(["qxmc"]).count()["xh"].sort_values(ascending=False)
# sn_cs_fir_name,sn_cs_sec_name,sn_cs_thi_name=sn_cs_data.index[:3]#计算城市流向前三
# sn_cs_fir_number,sn_cs_sec_number,sn_cs_thi_number=sn_cs_data[:3]
# sn_cs_fir_ratio,sn_cs_sec_ratio,sn_cs_thi_ratio=(sn_cs_data/sn_cs_data.sum())[:3]



# sn_cs1_zip=[decimal(sn_cs_fir_ratio),sn_cs_fir_ratio]#省内城市第一
# if sn_cs_fir_ratio>0.5:
#     color_now='#ffffff'
# else:
#     color_now=color_1
# sn_cs1_Liquid= (
#     Liquid()
#     .add(decimal(sn_cs_fir_ratio), sn_cs1_zip,color=[color_1],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
#         font_size=70,position="inside",color=color_now,font_family=font_2)
#         )
#     .set_global_opts(title_opts=opts.TitleOpts(title=sn_cs_fir_name,
#                                               pos_left="center",
#                                               pos_bottom="15%",
#                                               title_textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_1)
#                                               )
#                     )
# )

# sn_cs1_Liquid= (
# Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
# .add(sn_cs1_Liquid, grid_opts=opts.GridOpts())#位置调整
# )
# make_snapshot(snapshot,sn_cs1_Liquid.render(), pic_path+'市内区县流向1.png',pixel_ratio = 5)



# sn_cs2_zip=[decimal(sn_cs_sec_ratio),sn_cs_sec_ratio]#省内城市第二
# if sn_cs_sec_ratio>0.5:
#     color_now='#ffffff'
# else:
#     color_now=color_4
# sn_cs2_Liquid= (
#     Liquid()
#     .add(decimal(sn_cs_sec_ratio), sn_cs2_zip,color=[color_4],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
#         font_size=70,position="inside",color=color_now,font_family=font_2)
#         )
#     .set_global_opts(title_opts=opts.TitleOpts(title=sn_cs_sec_name,
#                                               pos_left="center",
#                                               pos_bottom="15%",
#                                               title_textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_4)
#                                               )
#                     )
# )
# sn_cs2_Liquid= (
# Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
# .add(sn_cs2_Liquid, grid_opts=opts.GridOpts())#位置调整
# )
# make_snapshot(snapshot,sn_cs2_Liquid.render(), pic_path+'市内区县流向2.png',pixel_ratio = 5)



# sn_cs3_zip=[decimal(sn_cs_thi_ratio),sn_cs_thi_ratio]#省内城市第三
# if sn_cs_thi_ratio>0.5:
#     color_now='#ffffff'
# else:
#     color_now=color_3
# sn_cs3_Liquid= (
#     Liquid()
#     .add(decimal(sn_cs_thi_ratio), sn_cs3_zip,color=[color_3],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
#         font_size=70,position="inside",color=color_now,font_family=font_2)
#         )
#     .set_global_opts(title_opts=opts.TitleOpts(title=sn_cs_thi_name,
#                                               pos_left="center",
#                                               pos_bottom="15%",
#                                               title_textstyle_opts=opts.TextStyleOpts(font_size = 45,font_family = font_3,color=color_3),
#                                               )
#                     )
# )

# sn_cs3_Liquid= (
# Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
# .add(sn_cs3_Liquid, grid_opts=opts.GridOpts())#位置调整
# )
# make_snapshot(snapshot,sn_cs3_Liquid.render(), pic_path+'市内区县流向3.png',pixel_ratio = 5)

# %% [markdown]
# ## 省内就业单位主要特征

# %%
#省内就业单位主要特征取数

sn_dwhy_ratio=(sn_data.query("dwjy=='是'").groupby(["dwhy"]).count()["xh"]/sn_data.query("dwjy=='是'").groupby(["dwhy"]).count()["xh"].sum()).sort_values(ascending=False)#单位行业
sn_dwxz_ratio=(sn_data.query("dwjy=='是'").groupby(["dwxz"]).count()["xh"]/sn_data.query("dwjy=='是'").groupby(["dwhy"]).count()["xh"].sum()).sort_values(ascending=False)#单位性质
sn_zwlx_ratio=(sn_data.query("dwjy=='是'").groupby(["gzzwlb"]).count()["xh"]/sn_data.query("dwjy=='是'").groupby(["dwhy"]).count()["xh"].sum()).sort_values(ascending=False)#职位类型

# %% [markdown]
# ## 继续深造率

# %%
#继续深造率
try:
    bys_sx_number=data_pq.groupby(['jylbfl']).count()["xh"]["升学"]#国内升学信息
    bys_sx_ratio=bys_sx_number/data_pq.groupby(['jylbfl']).count()["xh"].sum()
except:
    bys_sx_number=0
    bys_sx_ratio=0
    
try:
    bys_cg_number=data_pq.groupby(['jylbfl']).count()["xh"]["出国、出境"]#出国出境信息
    bys_cg_ratio=bys_cg_number/data_pq.groupby(['jylbfl']).count()["xh"].sum()
except:
    bys_cg_number=0
    bys_cg_ratio=0

# %% [markdown]
# ## 继续深造与专业相关度

# %%
#继续深造与专业相关度
zyxgd_number=data_dy.groupby(["dy_jxszzyxgd"]).count()['dy_xh'].sort_index(ascending=False)#专业相关度
zyxgd_ratio=zyxgd_number/data_dy.groupby(["dy_jxszzyxgd"]).count()['dy_xh'].sum()

zyxgd_index=zyxgd_number.index
zyxgd_zip=list(zip(zyxgd_index,zyxgd_ratio))
#继续深造与专业相关度
zyxgd_Pie= (
    Pie()
    .add('',zyxgd_zip,radius=["35%", "70%"],
        label_line_opts=opts.PieLabelLineOpts(length=20,length_2=30,linestyle_opts=opts.LineStyleOpts(width=5)),
        label_opts=opts.LabelOpts(interval=0,
        font_size=42,
        position="outside",
        formatter='{d|{d}}'+"%",
        rich={
            "d": {"fontSize": 45, "lineHeight": 200, "fontFamily":font_3},
            }
        )
        )
    .set_global_opts(
        title_opts=opts.TitleOpts(title=decimal(zyxgd_ratio['5']+zyxgd_ratio['4']+zyxgd_ratio['3']),
                                  pos_left="center",
                                  pos_bottom="45%",
                                  title_textstyle_opts=opts.TextStyleOpts(font_size =65,font_family = font_3,color=color_1),
                                  ),
        legend_opts=opts.LegendOpts(is_show=False)
                    )
    .set_colors([color_1,color_2,color_3,color_4,color_5])
)

zyxgd_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(zyxgd_Pie, grid_opts=opts.GridOpts())#位置调整
)
#zyxgd_Pie.render()
make_snapshot(snapshot,zyxgd_Pie.render(), pic_path+'继续深造与专业相关度.png',pixel_ratio = 5)

zyxgd_Pie.render_notebook()

# %% [markdown]
# ## 升学院校类型top3

# %%
#升学院校类型top3
sxlx_number=data_pq.query("gnsx=='是'").groupby(['sxgxlx']).count()["xh"].sort_values(ascending=False)

sxlx_fir_name,sxlx_sec_name,sxlx_thi_name=sxlx_number.index[:3]
sxlx_fir_number,sxlx_sec_number,sxlx_thi_number=sxlx_number[:3]
sxlx_fir_ratio,sxlx_sec_ratio,sxlx_thi_ratio=(sxlx_number/sxlx_number.sum())[:3]



sxlx_1_zip=[decimal(sxlx_fir_ratio),sxlx_fir_ratio]#升学院校类型第一
if sxlx_fir_ratio>0.5:
    color_now='#ffffff'
else:
    color_now=color_1
sxlx_1_Liquid= (
    Liquid()
    .add(decimal(sxlx_fir_ratio), sxlx_1_zip,color=[color_1],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
        font_size=70,position="inside",color=color_now)
        )
)

sxlx_1_Liquid= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(sxlx_1_Liquid, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,sxlx_1_Liquid.render(), pic_path+'升学院校类型1.png',pixel_ratio = 5)


sxlx_2_zip=[decimal(sxlx_sec_ratio),sxlx_sec_ratio]#升学院校类型第一
if sxlx_sec_ratio>0.5:
    color_now='#ffffff'
else:
    color_now=color_4
sxlx_2_Liquid= (
    Liquid()
    .add(decimal(sxlx_sec_ratio), sxlx_2_zip,color=[color_4],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
        font_size=70,position="inside",color=color_now)
        )
                    )


sxlx_2_Liquid= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(sxlx_2_Liquid, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,sxlx_2_Liquid.render(), pic_path+'升学院校类型2.png',pixel_ratio = 5)



sxlx_3_zip=[decimal(sxlx_thi_ratio),sxlx_thi_ratio]#升学院校类型第一
if sxlx_thi_ratio>0.5:
    color_now='#ffffff'
else:
    color_now=color_3
sxlx_3_Liquid= (
    Liquid()
    .add(decimal(sxlx_thi_ratio), sxlx_3_zip,color=[color_3],background_color='#ffffff',label_opts=opts.LabelOpts(interval=0,
        font_size=70,position="inside",color=color_now)
        )
                    )


sxlx_3_Liquid= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(sxlx_3_Liquid, grid_opts=opts.GridOpts())#位置调整
)
make_snapshot(snapshot,sxlx_3_Liquid.render(), pic_path+'升学院校类型3.png',pixel_ratio = 5)

# %% [markdown]
# ## 就业质量

# %%
#就业质量
jymyd=data_dy.groupby(["dy_jymyd"]).count()['dy_xh'].sort_index(ascending=False)#就业满意度
jymyd_ratio=(jymyd['5']+jymyd['4']+jymyd['3'])/jymyd.sum()

jyzyxgd=data_dy.groupby(["dy_jyzyxgd"]).count()['dy_xh'].sort_index(ascending=False)#就业专业相关度
jyzyxgd_ratio=(jyzyxgd['5']+jyzyxgd['4']+jyzyxgd['3'])/jyzyxgd.sum()

zyqdppd=data_dy.groupby(["dy_zwppd"]).count()['dy_xh'].sort_index(ascending=False)#职业期待匹配度
zyqdppd_ratio=(zyqdppd['5']+zyqdppd['4']+zyqdppd['3'])/zyqdppd.sum()

try:
    jywdx=data_dy.groupby(["dy_lzcs"]).count()['dy_xh'].sort_index(ascending=False)#就业稳定性
    jywdx_ratio=jywdx['0次']/jywdx.sum()
except:
    jywdx=data_dy.groupby(["dy_lzcs"]).count()['dy_xh'].sort_index(ascending=False)#就业稳定性
    jywdx_ratio=(jywdx['没有换工作单位但工作岗位有调整']+jywdx['没有换工作单位且工作岗位没有变化'])/jywdx.sum()

# %% [markdown]
# ## 教育教学反馈

# %%
#教育教学反馈

try:
    rcpymyd=data_dy.groupby(["dy_mxmyd"]).count()['dy_xh'].sort_index(ascending=False)#母校满意度
    rcpymyd_ratio=(rcpymyd['5']+rcpymyd['4']+rcpymyd['3'])/rcpymyd.sum()

except:
    rcpymyd=data_dy.groupby(["dy_rcpymyd"]).count()['dy_xh'].sort_index(ascending=False)#湖南省调研：人才培养满意度
    rcpymyd_ratio=(rcpymyd['5']+rcpymyd['4']+rcpymyd['3'])/rcpymyd.sum()


mxtjd=data_dy.groupby(["dy_mxtjd"]).count()['dy_xh'].sort_index(ascending=False)#母校推荐度
mxtjd_ratio=(mxtjd['5']+mxtjd['4']+mxtjd['3'])/mxtjd.sum()

try:
    jyjxmyd=data_dy.groupby(["dy_jyjx_zhmyd"]).count()['dy_xh'].sort_index(ascending=False)#教育教学满意度
    jyjxmyd_ratio=(jyjxmyd['5']+jyjxmyd['4']+jyjxmyd['3'])/jyjxmyd.sum()
except:
    jyjxmyd=data_dy.groupby(["dy_sjjxmyd"]).count()['dy_xh'].sort_index(ascending=False)#实践教学满意度
    jyjxmyd_ratio=(jyjxmyd['5']+jyjxmyd['4']+jyjxmyd['3'])/jyjxmyd.sum()


jycyfwmyd=data_dy.groupby(["dy_jycyfwmyd"]).count()['dy_xh'].sort_index(ascending=False)#就业创业服务满意度
jycyfwmyd_ratio=(jycyfwmyd['5']+jycyfwmyd['4']+jycyfwmyd['3'])/jycyfwmyd.sum()

# %% [markdown]
# ## 社会评价

# %%
#社会评价
cdy_bysmyd=data_dwdy.groupby(["cdy_bysmyd"]).count()["cdy_ybid"]#用人单位对毕业生满意度
cdy_bysmyd_ratio=(cdy_bysmyd['5']+cdy_bysmyd['4']+cdy_bysmyd['3'])/cdy_bysmyd.sum()

try:
    cdy_rcpymyd=data_dwdy.groupby(["cdy_rcpyppd"]).count()["cdy_ybid"]#用人单位对学校人才培养培满意度
    cdy_rcpymyd_ratio=(cdy_rcpymyd['5']+cdy_rcpymyd['4']+cdy_rcpymyd['3'])/cdy_rcpymyd.sum()
except:
    cdy_rcpymyd=data_dwdy.groupby(["cdy_rcpymyd"]).count()["cdy_ybid"]#用人单位对学校人才培养培满意度
    cdy_rcpymyd_ratio=(cdy_rcpymyd['5']+cdy_rcpymyd['4']+cdy_rcpymyd['3'])/cdy_rcpymyd.sum()

cdy_jyfwmyd=data_dwdy.groupby(["cdy_jyfwmyd"]).count()["cdy_ybid"]#用人单位对就业服务的满意度
cdy_jyfwmyd_ratio=(cdy_jyfwmyd['5']+cdy_jyfwmyd['4']+cdy_jyfwmyd['3'])/cdy_jyfwmyd.sum()


#用人单位对毕业生的满意度
cdy_bysmyd_Pie= (
    Pie()
    .add('',[('是',cdy_bysmyd_ratio),('否',1-cdy_bysmyd_ratio)],radius=["80%", "60%"],label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_1,color_7])
)

cdy_bysmyd_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(cdy_bysmyd_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,cdy_bysmyd_Pie.render(), pic_path+'用人单位对毕业生满意度.png',pixel_ratio = 5)



#用人单位对学校人才培养满意度
cdy_rcpymyd_Pie= (
    Pie()
    .add('',[('是',0.9927),('否',1-0.9927)],radius=["80%", "60%"],label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_4,color_9])
)

cdy_rcpymyd_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(cdy_rcpymyd_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,cdy_rcpymyd_Pie.render(), pic_path+'用人单位对人才培养满意度.png',pixel_ratio = 5)



#用人单位对学校就业服务满意度
cdy_jyfwmyd_Pie= (
    Pie()
    .add('',[('是',cdy_jyfwmyd_ratio),('否',1-cdy_jyfwmyd_ratio)],radius=["80%", "60%"],label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(legend_opts=opts.LegendOpts(is_show=False))
    .set_colors([color_3,color_9])
)

cdy_jyfwmyd_Pie= (
Grid(init_opts = opts.InitOpts(height = '800px',width='1050px'))  #设置图形大小,高度:height,宽度:width
.add(cdy_jyfwmyd_Pie, grid_opts=opts.GridOpts())
)#位置调整

make_snapshot(snapshot,cdy_jyfwmyd_Pie.render(), pic_path+'用人单位对就业服务培养满意度.png',pixel_ratio = 5)

# %%
cdy_rcpymyd_ratio

# %% [markdown]
# # 开始制作ppt

# %%
#创造一个ppt对象
prs = Presentation()
#设置幻灯片的大小
prs.slide_width = util.Cm(21)
prs.slide_height = util.Cm(29.7)

# %%
#定义写入文字函数，text文本框，content文本内容，line_space段间距，name字体名，size字体大小，bold字体加粗，colorRGB颜色，place是文本框对齐规则
def cre_text(text,content,line_space,name,size,bold,color,place):
    #设置文本框对象
    tf=text.text_frame
    tf.margin_top = util.Pt(0)  # 文本框上边距
    tf.margin_bottom = util.Pt(0)  # 文本框下边距
    tf.margin_left = util.Pt(0) # 文本框左边距0
    tf.margin_right = util.Pt(0)
    tf.vertical_anchor = MSO_ANCHOR.MIDDLE# 文本框中文本的垂直对齐方式：居中对齐
    tf.word_wrap = True # 设置文字自动换行
    #添加内容
    p= tf.paragraphs[0]#这里不能用add_paragrahph，那样会凭空多一行空白
    p.text = content # 文本框内容
    p.alignment = place#设置
    p.line_spacing = line_space
    #设置字体格式
    f=p.font#设置字体对象
    f.name =name#字体格式
    f.size = util.Pt(size)#设置字体大小
    f.bold = bold#字体加粗
    f.color.rgb = color#通过绝对字体颜色进行锁定
    
def decimal(number):#保证比例固定两位小数
    out=str(Decimal(number*100).quantize(Decimal("0.00")))+'%'
    return out



#自选矩形框框的图例，因为是在生源结构图写的所以起的这个函数名字
def add_dylxt_icon(slide,left,top,width,height,color):#生源结构图图标
    shape=slide.shapes.add_shape(MSO_SHAPE.RECTANGLE,util.Cm(left),util.Cm(top),util.Cm(width),util.Cm(height))
    fill=shape.fill
    fill.solid()
    fill.fore_color.rgb=color
    shadow=shape.shadow
    shadow.inherit = False
    shadow.visible = False
    #无边框线条
    line=shape.line
    line.fill.background()

# %% [markdown]
# # 开始第一页

# %%
#插入一个模板  其中六号模板是默认的空板式
slide_1 = prs.slides.add_slide(prs.slide_layouts[6])
#left top 用来定义位置，width,high确定大小

#报告综述标题
shape_1_1=slide_1.shapes.add_picture(pic_path+'报告综述标题.png',util.Cm(2.51),util.Cm(1.57),util.Cm(15.99),util.Cm(2.83))
# #添加文本框
# text_1_1=slide_1.shapes.add_textbox(util.Cm(8.08),util.Cm(1.64),util.Cm(6),util.Cm(1.96))

# cre_text(text_1_1,
#          '报告综述',
#          1.5 ,
#          font_1,
#          32,
#          True,
#          RGBColor(255,255,255),
#          PP_ALIGN.LEFT)

# %%
#标题1，毕业生规模与结构
shape_1_2=slide_1.shapes.add_picture(pic_path+'标题1.png',util.Cm(2.5),util.Cm(6),util.Cm(16.16 ),util.Cm(4.35))

# %%
#毕业生的性别结构标题
shape_1_3=slide_1.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.43),util.Cm(8.73),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_1_3=slide_1.shapes.add_textbox(util.Cm(4),util.Cm(9.68),util.Cm(7),util.Cm(1.28))

cre_text(text_1_3,
         '毕业生的性别结构',
         1.5 ,
         font_2,
         18,
         False,
         color1,
         PP_ALIGN.LEFT)

# %%
#毕业生性别气泡框 
shape_1_4=slide_1.shapes.add_picture(pic_path+'毕业生性别气泡框.png',util.Cm(3.05),util.Cm(11.28),util.Cm(7.31),util.Cm(4.34))

#添加文本框
text_1_4=slide_1.shapes.add_textbox(util.Cm(3.74),util.Cm(11.84),util.Cm(5.53),util.Cm(3.2))

cre_text(text_1_4,
         xxmc+bynd+f'届总毕业生人数为{bys_all_number}人，男生占'+decimal(bys_nan_ratio)+f'，女生占'+decimal(bys_nv_ratio),
         1.5 ,
         font_3,
         12,
         False,
         color1,
         PP_ALIGN.LEFT)

# %%
#毕业生性别结构圆环图  毕业生性别圆环
shape_1_5=slide_1.shapes.add_picture(pic_path+'毕业生性别圆环.png',util.Cm(11.15),util.Cm(10.6),util.Cm(7.55),util.Cm(4.83))

# %%
#毕业生的生源结构标题
shape_1_6=slide_1.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.45 ),util.Cm(17.14),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_1_6=slide_1.shapes.add_textbox(util.Cm(4.15),util.Cm(18.09),util.Cm(6),util.Cm(1.28))

cre_text(text_1_6,
         '毕业生的生源结构',
         1.5 ,
         font_2,
         18,
         False,
         color1,
         PP_ALIGN.LEFT)

# %%
#生源结构地图描述区域
shape_1_7=slide_1.shapes.add_picture(pic_path+'地图定位图标.png',util.Cm(12.35),util.Cm(19.69),util.Cm(0.52),util.Cm(0.68))

text_1_7=slide_1.shapes.add_textbox(util.Cm(13.05),util.Cm(19.52),util.Cm(3),util.Cm(1.02))

cre_text(text_1_7,
         '省内生源',
         1.5 ,
         font_2,
         14,
         False,
         color1,
         PP_ALIGN.LEFT)
                                    
#具体省内的结构数据                             
text_1_7_0=slide_1.shapes.add_textbox(util.Cm(13.05),util.Cm(20.52 ),util.Cm(6),util.Cm(0.9))

cre_text(text_1_7_0,
         f'{xxsf}{bys_sn_number}人，占比'+decimal(bys_sn_ratio),
         1.5 ,
         font_3,
         12,
         False,
         color1,
         PP_ALIGN.LEFT)

# %%
#生源结构地图描述区域
shape_1_8=slide_1.shapes.add_picture(pic_path+'地图定位图标.png',util.Cm(12.35),util.Cm(22.14),util.Cm(0.52),util.Cm(0.68))

text_1_8=slide_1.shapes.add_textbox(util.Cm(13.05),util.Cm(21.97),util.Cm(3),util.Cm(1.02))

cre_text(text_1_8,
         '省外生源',
         1.5 ,
         font_2,
         14,
         False,
         color1,PP_ALIGN.LEFT)  

text_1_8_0=slide_1.shapes.add_textbox(util.Cm(13.07),util.Cm(23.16),util.Cm(10),util.Cm(0.82))
text_1_8_1=slide_1.shapes.add_textbox(util.Cm(13.07),util.Cm(24.23),util.Cm(10),util.Cm(0.82))
text_1_8_2=slide_1.shapes.add_textbox(util.Cm(13.07),util.Cm(25.35),util.Cm(10),util.Cm(0.82))
text_1_8_3=slide_1.shapes.add_textbox(util.Cm(13.07),util.Cm(26.39),util.Cm(10),util.Cm(0.82))
#省外生源信息框
sy_name_box=[text_1_8_0,text_1_8_1,text_1_8_2,text_1_8_3]
sy_content_box=[
f'{bys_sw_fir_name}{bys_sw_fir_number}人，占比'+decimal(bys_sw_fir_ratio),
f'{bys_sw_sec_name}{bys_sw_sec_number}人，占比'+decimal(bys_sw_sec_ratio),
f'{bys_sw_thi_name}{bys_sw_thi_number}人，占比'+decimal(bys_sw_thi_ratio),
f'其他区域{bys_sw_number.sum()-bys_sw_fir_number-bys_sw_sec_number-bys_sw_thi_number}人，占比'+decimal(1-bys_sw_fir_ratio-bys_sw_sec_ratio-bys_sw_thi_ratio-bys_sn_ratio) 
]
#色彩
color_box=[color2,color3,color4,color1]
for i in range(len(sy_name_box)):
    cre_text(sy_name_box[i],
         sy_content_box[i],
         1.5 ,
         font_3,
         12,
         False,
         color_box[i],PP_ALIGN.LEFT
        )



#添加小图标
add_dylxt_icon(slide_1,12.29 ,20.87,0.66,0.45,color1)
add_dylxt_icon(slide_1,12.29 ,23.46,0.66,0.45,color2)
add_dylxt_icon(slide_1,12.29 ,24.53,0.66,0.45,color3)
add_dylxt_icon(slide_1,12.29 ,25.6,0.66,0.45,color4)
add_dylxt_icon(slide_1,12.29 ,26.67,0.66,0.45,color7)

# %%
#生源结构地图
shape_1_9=slide_1.shapes.add_picture(pic_path+'生源结构地图.png',util.Cm(-1.25),util.Cm(19.78),util.Cm(14.7),util.Cm(8.06))

# %% [markdown]
# # 开始第二页

# %%
#插入一个模板  其中六号模板是默认的空板式
slide_2 = prs.slides.add_slide(prs.slide_layouts[6])
#left top 用来定义位置，width,high确定大小

# %%
#标题2，毕业生毕业去向落实情况
shape_2_1=slide_2.shapes.add_picture(pic_path+'标题2.png',util.Cm(2.48),util.Cm(2.25),util.Cm(16.13),util.Cm(4.35))

# %%
#毕业生的生源结构标题
shape_2_2=slide_2.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.51),util.Cm(4.94),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_2_2=slide_2.shapes.add_textbox(util.Cm(4.07),util.Cm(5.89),util.Cm(7),util.Cm(1.28))

cre_text(text_2_2,
         '毕业生毕业去向7个率',
         1.5 ,
         font_2,
         18,
         False,
         color1,
         PP_ALIGN.LEFT)

# %%
#毕业去向落实率水滴图
shape_2_3=slide_2.shapes.add_picture(pic_path+'毕业去向落实率水滴图.png',util.Cm(-1.09),util.Cm(4.91),util.Cm(15.12),util.Cm(11.33))

# %%
def add_flow(slide,left,top,width,height,color):#浅色底板内容
    shape=slide.shapes.add_shape(MSO_SHAPE.RECTANGLE,util.Cm(left),util.Cm(top),util.Cm(width),util.Cm(height))
    fill=shape.fill
    fill.solid()
    fill.fore_color.rgb=color
    #无边框线条
    line=shape.line
    line.fill.background()
    #阴影
    shadow=shape.shadow
    shadow.inherit = False
    shadow.visible = False

 
#先加载浅色底板
add_flow(slide_2,12.94,  7.34,  5.44,  0.98,color7)
add_flow(slide_2,12.94,  8.51,  5.44,  0.98,color7)
add_flow(slide_2,12.94,  9.6,  5.44,  0.98,color7)
add_flow(slide_2,12.94,  10.72,  5.44,  0.98,color7)
add_flow(slide_2,12.94,  11.87,  5.44,  0.98,color7)
add_flow(slide_2,12.94,  12.96,  5.44,  0.98,color7)

#再加载深色底板
add_flow(slide_2,12.94,  7.34,  5.44*xyhtjy_ratio,  0.98,color1)#协议和合同就业率
add_flow(slide_2,12.94,  8.51,  5.44*jxsz_ratio,  0.98,color1)#继续深造率
add_flow(slide_2,12.94,  9.6,   5.44*zzcy_ratio,  0.98,color1)#自主创业率
add_flow(slide_2,12.94,  10.72,  5.44*lhjy_ratio,  0.98,color1)#灵活就业率
add_flow(slide_2,12.94,  11.87,  5.44*zbjy_ratio,  0.98,color1)#暂不就业率
add_flow(slide_2,12.94,  12.96,  5.44*djy_ratio,  0.98,color1)#待就业率

def text_flow(slide,ratio,height):
    if ratio<0.5:
        text=slide.shapes.add_textbox(util.Cm(12.94+5.44*ratio+0.3),util.Cm(height),util.Cm(3),util.Cm(0.94))
        cre_text(text,
         decimal(ratio),
         1.5 ,
         font_2,
         12,
         False,
         color1, 
         PP_ALIGN.LEFT)  
    elif ratio>=0.5:
        text=slide.shapes.add_textbox(util.Cm(12.94+5.44*ratio-3.25),util.Cm(height),util.Cm(3),util.Cm(0.94))
        cre_text(text,
         decimal(ratio),
         1.5 ,
         font_2,
         12,
         False,
         RGBColor(255,255,255),
         PP_ALIGN.RIGHT) 

text_flow(slide_2,xyhtjy_ratio,7.34)
text_flow(slide_2,jxsz_ratio,8.51)
text_flow(slide_2,zzcy_ratio,9.6)
text_flow(slide_2,lhjy_ratio,10.72)
text_flow(slide_2,zbjy_ratio,11.87)
text_flow(slide_2,djy_ratio,12.96)


text_2_3_1=slide_2.shapes.add_textbox(util.Cm(8.71),util.Cm(7.34),util.Cm(4),util.Cm( 0.98))
text_2_3_2=slide_2.shapes.add_textbox(util.Cm(8.71),util.Cm(8.51),util.Cm(4),util.Cm( 0.98))
text_2_3_3=slide_2.shapes.add_textbox(util.Cm(8.71),util.Cm(9.6),util.Cm(4),util.Cm( 0.98))
text_2_3_4=slide_2.shapes.add_textbox(util.Cm(8.71),util.Cm(10.72),util.Cm(4),util.Cm( 0.98))
text_2_3_5=slide_2.shapes.add_textbox(util.Cm(8.71),util.Cm(11.87),util.Cm(4),util.Cm( 0.98))
text_2_3_6=slide_2.shapes.add_textbox(util.Cm(8.71),util.Cm(12.96),util.Cm(4),util.Cm( 0.98))
byqx_list=['协议和合同就业','继续深造','自主创业','灵活就业','暂不就业','待就业']
byqx_index_list=[text_2_3_1,text_2_3_2,text_2_3_3,text_2_3_4,text_2_3_5,text_2_3_6]

for i in range(6):
    cre_text(byqx_index_list[i],
         byqx_list[i],
         1.5 ,
         font_3,
         12,
         False,
         color1,
         PP_ALIGN.RIGHT)

# %%
#标题3,毕业生就业流向
shape_2_4=slide_2.shapes.add_picture(pic_path+'标题3.png',util.Cm(2.48),util.Cm(14.89),util.Cm(16.05),util.Cm(4.35))

# %%
#毕业生的生源结构标题
shape_2_5=slide_2.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.5),util.Cm(17.6),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_2_5=slide_2.shapes.add_textbox(util.Cm(4.06),util.Cm(18.52),util.Cm(7),util.Cm(1.28))

cre_text(text_2_5,
         '就业单位主要特征',
         1.5 ,
         font_2,
         18,
         False,
         color1, PP_ALIGN.LEFT)

# %%
#就业单位三个圆固定部分
shape_2_6_1=slide_2.shapes.add_picture(pic_path+'单位行业圆.png',util.Cm(2.52),util.Cm(21.59 ),util.Cm(5.64),util.Cm(5.16))
shape_2_6_2=slide_2.shapes.add_picture(pic_path+'单位性质圆.png',util.Cm(7.66),util.Cm(21.59),util.Cm(5.64),util.Cm(5.16))
shape_2_6_3=slide_2.shapes.add_picture(pic_path+'职位类型圆.png',util.Cm(12.84),util.Cm(21.59 ),util.Cm(5.64),util.Cm(5.16))

#就业单位圆内信息框
text_2_6_1=slide_2.shapes.add_textbox(util.Cm(4.92),util.Cm(24.15),util.Cm(1.15),util.Cm(1.28))
text_2_6_2=slide_2.shapes.add_textbox(util.Cm(10.04),util.Cm(23.2),util.Cm(1.15),util.Cm(1.28))
text_2_6_3=slide_2.shapes.add_textbox(util.Cm(15.29),util.Cm(24.16),util.Cm(1.15),util.Cm(1.28))

yn_text_name=[text_2_6_1,text_2_6_2,text_2_6_3]
yn_content_name=['单位行业','单位性质','职位类型']
color_box=[color1,color3,color2]
for i in range(3):
    cre_text(yn_text_name[i],
         yn_content_name[i],
         1 ,
         font_2,
         12,
         False,
         color_box[i], PP_ALIGN.LEFT) 

#text2_7的内容是文字内容
text_2_7_1=slide_2.shapes.add_textbox(util.Cm(3.8),util.Cm(20.15),util.Cm(3.1),util.Cm(1.2))
text_2_7_2=slide_2.shapes.add_textbox(util.Cm(1.85),util.Cm(26.84),util.Cm(3.1),util.Cm(1.2))
text_2_7_3=slide_2.shapes.add_textbox(util.Cm(5.63 ),util.Cm(26.84),util.Cm(3.1),util.Cm(1.2))
text_2_7_4=slide_2.shapes.add_textbox(util.Cm(7.11 ),util.Cm(20.15),util.Cm(3.1),util.Cm(1.2))
text_2_7_5=slide_2.shapes.add_textbox(util.Cm(10.73),util.Cm(20.15),util.Cm(3.1),util.Cm(1.2))
text_2_7_6=slide_2.shapes.add_textbox(util.Cm(8.92),util.Cm(26.84),util.Cm(3.1),util.Cm(1.2))
text_2_7_7=slide_2.shapes.add_textbox(util.Cm(14.14),util.Cm(20.15 ),util.Cm(3.1),util.Cm(1.2))
text_2_7_8=slide_2.shapes.add_textbox(util.Cm(12.33),util.Cm(26.84),util.Cm(3.1),util.Cm(1.2))
text_2_7_9=slide_2.shapes.add_textbox(util.Cm(15.94 ),util.Cm(26.84),util.Cm(3.1),util.Cm(1.2))
#text2_8的内容 是数字内容
text_2_8_1=slide_2.shapes.add_textbox(util.Cm(4.65),util.Cm(22.18 ),util.Cm(3.1),util.Cm(0.68))
text_2_8_2=slide_2.shapes.add_textbox(util.Cm(2.85),util.Cm(25.31 ),util.Cm(3.1),util.Cm(0.68))
text_2_8_3=slide_2.shapes.add_textbox(util.Cm(6.53),util.Cm(25.34),util.Cm(3.1),util.Cm(0.68))
text_2_8_4=slide_2.shapes.add_textbox(util.Cm(8.03),util.Cm(22.21),util.Cm(3.1),util.Cm(0.68))
text_2_8_5=slide_2.shapes.add_textbox(util.Cm(11.68),util.Cm(22.21),util.Cm(3.1),util.Cm(0.68))
text_2_8_6=slide_2.shapes.add_textbox(util.Cm(9.94),util.Cm(25.35),util.Cm(3.1),util.Cm(0.68))
text_2_8_7=slide_2.shapes.add_textbox(util.Cm(15),util.Cm(22.19 ),util.Cm(3.1),util.Cm(0.68))
text_2_8_8=slide_2.shapes.add_textbox(util.Cm(13.18),util.Cm(25.32),util.Cm(3.1),util.Cm(0.68))
text_2_8_9=slide_2.shapes.add_textbox(util.Cm(16.86),util.Cm(25.32),util.Cm(3.1),util.Cm(0.68))
#圆外信息框
yw_content_name=list(bys_dwhy_ratio.index[:3])+list(bys_dwxz_ratio.index[:3])+list(bys_zwlx_ratio.index[:3])+list(bys_dwhy_ratio[:3])+list(bys_dwxz_ratio[:3])+list(bys_zwlx_ratio[:3])
yw_text_name=[text_2_7_1,text_2_7_2,text_2_7_3,text_2_7_4,text_2_7_5,text_2_7_6,text_2_7_7,text_2_7_8,text_2_7_9,text_2_8_1,text_2_8_2,text_2_8_3,text_2_8_4,text_2_8_5,text_2_8_6,text_2_8_7,text_2_8_8,text_2_8_9]
#色彩
color_box=[color1,color1,color1,color3,color3,color3,color2,color2,color2]

for i in range(9):
    cre_text(yw_text_name[i],
         yw_content_name[i],
         1.5 ,
         font_3,
         10,
         False,
         color_box[i], PP_ALIGN.CENTER) 

for j in range(9,18):
    cre_text(yw_text_name[j],
         decimal(yw_content_name[j]),
         1.5 ,
         font_2,
         10,
         False,
         RGBColor(255,255,255), PP_ALIGN.LEFT)

# %% [markdown]
# # 开始第三页

# %%
#插入一个模板  其中六号模板是默认的空板式
slide_3 = prs.slides.add_slide(prs.slide_layouts[6])
#left top 用来定义位置，width,high确定大小

# %%
#重点战略地区标题
shape_3_1=slide_3.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.5),util.Cm(2.05),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_3_1=slide_3.shapes.add_textbox(util.Cm(4.06),util.Cm(3.02),util.Cm(7),util.Cm(1.03))

cre_text(text_3_1,
         '重点战略地区',
         1.5 ,
         font_2,
         18,
         False,
         color1, PP_ALIGN.LEFT)

# %%
#重点战略地区
shape_3_2=slide_3.shapes.add_picture(pic_path+'重点战略地区圆角矩形框.png',util.Cm(3.14),util.Cm(4.96),util.Cm(14.6),util.Cm(1.2))

#添加文本框
text_3_2=slide_3.shapes.add_textbox(util.Cm(4.04),util.Cm(5.05),util.Cm(14),util.Cm(0.9))

cre_text(text_3_2,
         '学校鼓励和引导毕业生围绕“六大区域”战略就业择业。',
         1.5 ,
         font_3,
         14,
         False,
         RGBColor(255,255,255), PP_ALIGN.LEFT)

# %%
#重点战略地区六个图
shape_3_3_1=slide_3.shapes.add_picture(pic_path+'长江经济带.png',util.Cm(2.43),util.Cm(6.59),util.Cm(5.8),util.Cm(4.45))
shape_3_3_2=slide_3.shapes.add_picture(pic_path+'一带一路经济带.png',util.Cm(7.63),util.Cm(6.59),util.Cm(5.8),util.Cm(4.45))
shape_3_3_3=slide_3.shapes.add_picture(pic_path+'长江三角洲区域.png',util.Cm(12.77),util.Cm(6.59),util.Cm(5.8),util.Cm(4.45))
shape_3_3_4=slide_3.shapes.add_picture(pic_path+'京津冀区域.png',util.Cm(2.43),util.Cm(11.51),util.Cm(5.8),util.Cm(4.45))
shape_3_3_5=slide_3.shapes.add_picture(pic_path+'粤港澳大湾区.png',util.Cm(7.63),util.Cm(11.51),util.Cm(5.8),util.Cm(4.45))
shape_3_3_6=slide_3.shapes.add_picture(pic_path+'黄河流域.png',util.Cm(12.77),util.Cm(11.51),util.Cm(5.8),util.Cm(4.45))

#text3_3的内容是文字内容
text_3_3_1=slide_3.shapes.add_textbox(util.Cm(3.88),util.Cm(8.1),util.Cm(3),util.Cm(0.68))
text_3_3_2=slide_3.shapes.add_textbox(util.Cm(8.95),util.Cm(8.1),util.Cm(3),util.Cm(0.68))
text_3_3_3=slide_3.shapes.add_textbox(util.Cm(14.18),util.Cm(8.1),util.Cm(3),util.Cm(0.68))
text_3_3_4=slide_3.shapes.add_textbox(util.Cm(3.88),util.Cm(12.94),util.Cm(3),util.Cm(0.68))
text_3_3_5=slide_3.shapes.add_textbox(util.Cm(8.95),util.Cm(12.94),util.Cm(3),util.Cm(0.68))
text_3_3_6=slide_3.shapes.add_textbox(util.Cm(14.18),util.Cm(12.94),util.Cm(3),util.Cm(0.68))

#text3_4的内容 是数字内容
text_3_4_1=slide_3.shapes.add_textbox(util.Cm(3.95),util.Cm(8.76),util.Cm(3),util.Cm(0.95))
text_3_4_2=slide_3.shapes.add_textbox(util.Cm(9.08),util.Cm(8.76),util.Cm(3),util.Cm(0.95))
text_3_4_3=slide_3.shapes.add_textbox(util.Cm(14.22),util.Cm(8.76),util.Cm(3),util.Cm(0.95))
text_3_4_4=slide_3.shapes.add_textbox(util.Cm(3.95),util.Cm(13.6),util.Cm(3),util.Cm(0.95))
text_3_4_5=slide_3.shapes.add_textbox(util.Cm(9.08),util.Cm(13.6),util.Cm(3),util.Cm(0.95))
text_3_4_6=slide_3.shapes.add_textbox(util.Cm(14.22),util.Cm(13.6),util.Cm(3),util.Cm(0.95))

#战略地区
dq_content_name=['长江经济带','一带一路经济带','长江三角洲区域','京津冀区域','粤港澳大湾区','黄河流域',
             decimal(bys_cjjjd_ratio),decimal(bys_ydyl_ratio),decimal(bys_csj_ratio),decimal(bys_jjj_ratio),decimal(bys_yga_ratio),decimal(bys_hhly_ratio)]
dq_text_name=[text_3_3_1,text_3_3_2,text_3_3_3,text_3_3_4,text_3_3_5,text_3_3_6,text_3_4_1,text_3_4_2,text_3_4_3,text_3_4_4,text_3_4_5,text_3_4_6]

for i in range(6):
    cre_text(dq_text_name[i],
         dq_content_name[i],
         1.5 ,
         font_3,
         10,
         False,
         color1, PP_ALIGN.CENTER) 

for j in range(6,12):
    cre_text(dq_text_name[j],
         dq_content_name[j],
         1.5 ,
         font_2,
         14,
         False,
         color1, PP_ALIGN.CENTER)

# %%
#地域流向
shape_3_5=slide_3.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.5),util.Cm(17.07),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_3_5=slide_3.shapes.add_textbox(util.Cm(4.06),util.Cm(18.),util.Cm(5),util.Cm(1.28))

cre_text(text_3_5,
         '地域流向',
         1.5 ,
         font_2,
         18,
         False,
         color1,PP_ALIGN.LEFT)

# %%
#地域流向图
shape_3_6=slide_3.shapes.add_picture(pic_path+'地域流向图.png',util.Cm(-1.22),util.Cm(18.77 ),util.Cm(15.44),util.Cm(8.37))

# %%
#地域流向图的图例

#添加小图标
add_dylxt_icon(slide_3,12.04 ,21.19,0.66,0.53,color1)
add_dylxt_icon(slide_3,12.04 ,22.3,0.66,0.53,color2)
add_dylxt_icon(slide_3,12.04 ,23.31,0.66,0.53,color3)
add_dylxt_icon(slide_3,12.04 ,24.41,0.66,0.53,color4)
add_dylxt_icon(slide_3,12.04 ,25.43,0.66,0.53,color7)

text_3_7_1=slide_3.shapes.add_textbox(util.Cm(13.4),util.Cm(21.12),util.Cm(10),util.Cm(0.53))
text_3_7_2=slide_3.shapes.add_textbox(util.Cm(13.4),util.Cm(22.23),util.Cm(10),util.Cm( 0.53))
text_3_7_3=slide_3.shapes.add_textbox(util.Cm(13.4),util.Cm(23.24),util.Cm(10),util.Cm( 0.53))
text_3_7_4=slide_3.shapes.add_textbox(util.Cm(13.4),util.Cm(24.34),util.Cm(10),util.Cm( 0.53))
text_3_7_5=slide_3.shapes.add_textbox(util.Cm(13.4),util.Cm(25.36),util.Cm(10),util.Cm( 0.53))
dylx_list=[
f'{bys_dy_fir_name}{bys_dy_fir_number}人,占比{decimal(bys_dy_fir_ratio)}',
f'{bys_dy_sec_name}{bys_dy_sec_number}人,占比{decimal(bys_dy_sec_ratio)}',
f'{bys_dy_thi_name}{bys_dy_thi_number}人,占比{decimal(bys_dy_thi_ratio)}',
f'{bys_dy_for_name}{bys_dy_for_number}人,占比{decimal(bys_dy_for_ratio)}',
f'其他区域{bys_dy_number.sum()-bys_dy_fir_number-bys_dy_sec_number-bys_dy_thi_number-bys_dy_for_number}人,占比{decimal(1-bys_dy_fir_ratio-bys_dy_sec_ratio-bys_dy_thi_ratio-bys_dy_for_ratio)}',
]
dylx_index_list=[text_3_7_1,text_3_7_2,text_3_7_3,text_3_7_4,text_3_7_5]
colorbox=[color1,color2,color3,color4,color1]
for i in range(5):
    cre_text(dylx_index_list[i],
         dylx_list[i],
         1.5 ,
         font_2,
         14,
         False,
         colorbox[i],
         PP_ALIGN.LEFT)

# %% [markdown]
# # 开始第四页

# %%
#插入一个模板  其中六号模板是默认的空板式
slide_4 = prs.slides.add_slide(prs.slide_layouts[6])
#left top 用来定义位置，width,high确定大小

# %%
#标题4
shape_4_1=slide_4.shapes.add_picture(pic_path+'标题4.png',util.Cm(2.46),util.Cm(2.25),util.Cm(16.13),util.Cm(4.35))

# %%
#省内城市流向Top3
shape_4_2=slide_4.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.45),util.Cm(4.91),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_4_2=slide_4.shapes.add_textbox(util.Cm(4.15),util.Cm(5.87),util.Cm(7),util.Cm(1.28))

cre_text(text_4_2,
         '省内城市流向Top3',
         1.5 ,
         font_2,
         18,
         False,
         color1, PP_ALIGN.LEFT)

# %%
#省内城市流向图
shape_4_3_1=slide_4.shapes.add_picture(pic_path+'省内城市流向1.png',util.Cm(-0.27 ),util.Cm(5.87),util.Cm(11.05),util.Cm(8.16))
shape_4_3_2=slide_4.shapes.add_picture(pic_path+'省内城市流向2.png',util.Cm(4.98),util.Cm(5.87),util.Cm(11.05),util.Cm(8.16))
shape_4_3_3=slide_4.shapes.add_picture(pic_path+'省内城市流向3.png',util.Cm(10.25),util.Cm(5.87),util.Cm(11.05),util.Cm(8.16))

# %%
#省内城市流向Top3
shape_4_4=slide_4.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.56),util.Cm(14.22),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_4_4=slide_4.shapes.add_textbox(util.Cm(4.26),util.Cm(15.57),util.Cm(8),util.Cm(1.223))

cre_text(text_4_4,
         '省内就业单位主要特征',
         1.5 ,
         font_2,
         18,
         False,
         color1, PP_ALIGN.LEFT)

# %%
#省内就业
#就业单位三个圆固定部分
shape_4_5_1=slide_4.shapes.add_picture(pic_path+'单位行业圆.png',util.Cm(6.86),util.Cm(19.29),util.Cm(7.78),util.Cm(7.11))

text_4_5_1=slide_4.shapes.add_textbox(util.Cm(10.09),util.Cm(22.33),util.Cm(1.34),util.Cm(1.90))

cre_text(text_4_5_1,
     '单位行业',
     1 ,
     font_1,
     16.54,
     False,
     color1, PP_ALIGN.CENTER) 

#text4_6的内容是文字内容
text_4_6_1=slide_4.shapes.add_textbox(util.Cm(8.35),util.Cm(17.83),util.Cm(5),util.Cm(0.82))
text_4_6_2=slide_4.shapes.add_textbox(util.Cm(5.76),util.Cm(26.67),util.Cm(5),util.Cm(0.82))
text_4_6_3=slide_4.shapes.add_textbox(util.Cm(11.08),util.Cm(26.67),util.Cm(5),util.Cm(0.82))

#text4_7的内容 是数字内容
text_4_7_1=slide_4.shapes.add_textbox(util.Cm(9.37),util.Cm(20.12 ),util.Cm(3),util.Cm(0.94))
text_4_7_2=slide_4.shapes.add_textbox(util.Cm(6.93),util.Cm(24.53),util.Cm(3),util.Cm(0.94))
text_4_7_3=slide_4.shapes.add_textbox(util.Cm(11.97),util.Cm(24.53),util.Cm(3),util.Cm(0.94))

#圆外信息框
snyw_content_name=list(sn_dwhy_ratio.index[:3])+list(sn_dwhy_ratio[:3])
snyw_text_name=[text_4_6_1,text_4_6_2,text_4_6_3,text_4_7_1,text_4_7_2,text_4_7_3]

for i in range(3):
    cre_text(snyw_text_name[i],
         snyw_content_name[i],
         1.5 ,
         font_3,
         12,
         False,
         color1,PP_ALIGN.CENTER) 

for j in range(3,6):
    cre_text(snyw_text_name[j],
         decimal(snyw_content_name[j]),
         1.5 ,
         font_1,
         13.78,
         False,
         RGBColor(255,255,255), PP_ALIGN.CENTER)

# %% [markdown]
# # 开始第五页

# %%
#插入一个模板  其中六号模板是默认的空板式
slide_5 = prs.slides.add_slide(prs.slide_layouts[6])
#left top 用来定义位置，width,high确定大小

# %%
#标题5
shape_5_1=slide_5.shapes.add_picture(pic_path+'标题5.png',util.Cm(2.48),util.Cm(2.35),util.Cm(16.13),util.Cm(4.35))

# %%
#省内单位流向
shape_5_2=slide_5.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.56),util.Cm(4.97),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_5_2=slide_5.shapes.add_textbox(util.Cm(4.27),util.Cm(5.88),util.Cm(8),util.Cm(1.28))

cre_text(text_5_2,
         '继续深造率',
         1.5 ,
         font_2,
         18,
         False,
         color1, PP_ALIGN.LEFT)

# %%
#省内单位 图标图
shape_5_3_1=slide_5.shapes.add_picture(pic_path+'学士帽.png',util.Cm(2.93),util.Cm(7.68),util.Cm(3.02),util.Cm(2.23))
shape_5_3_2=slide_5.shapes.add_picture(pic_path+'飞机图.png',util.Cm(7.35),util.Cm(7.48),util.Cm(2.67),util.Cm(2.67))

text_5_3_1=slide_5.shapes.add_textbox(util.Cm(2.91),util.Cm(10.4),util.Cm(3),util.Cm(1.09))
text_5_3_2=slide_5.shapes.add_textbox(util.Cm(4.57),util.Cm(10.4),util.Cm(3),util.Cm(1.09))
text_5_3_3=slide_5.shapes.add_textbox(util.Cm(3.31),util.Cm(11.1),util.Cm(5),util.Cm(1.15))
text_5_3_4=slide_5.shapes.add_textbox(util.Cm(7.17),util.Cm(10.4),util.Cm(3),util.Cm(1.09))
text_5_3_5=slide_5.shapes.add_textbox(util.Cm(8.71),util.Cm(10.4),util.Cm(3),util.Cm(1.09))
text_5_3_6=slide_5.shapes.add_textbox(util.Cm(7.56),util.Cm(11.12),util.Cm(5),util.Cm(1.15))
#省内流向信息
snlx_content_name=[f'{bys_sx_number}人',decimal(bys_sx_ratio),'国内升学',f'{bys_cg_number}人',decimal(bys_cg_ratio),'出国（境）']
snlx_text_name=[text_5_3_1,text_5_3_2,text_5_3_3,text_5_3_4,text_5_3_5,text_5_3_6]
color_box=[color1,color1,color1,color3,color3,color3,color2,color2,color2]

for i in range(6):
    cre_text(snlx_text_name[i],
         snlx_content_name[i],
         1.5 ,
         font_2,
         16,
         False,
         color_box[i], PP_ALIGN.LEFT)

# %%
#省内单位气泡图
shape_5_4=slide_5.shapes.add_picture(pic_path+'省内单位气泡框.png',util.Cm(11.19),util.Cm(7.47),util.Cm(7.31),util.Cm(4.34))

text_5_4=slide_5.shapes.add_textbox(util.Cm(12.2),util.Cm(8.06),util.Cm(5.72),util.Cm(3.15))

cre_text(text_5_4,
         f'本校{bynd}届毕业生继续深造总人数{bys_sx_number+bys_cg_number}人，占毕业生人数的'+decimal(bys_sx_ratio+bys_cg_ratio)+f'，其中，国内升学{bys_sx_number}人，出国出境{bys_cg_number}人。',
         1.5 ,
         font_3,
         12,
         False,
         color1, PP_ALIGN.LEFT)

# %%
#继续深造与专业相关度
shape_5_5=slide_5.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.56),util.Cm(12.38),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_5_5=slide_5.shapes.add_textbox(util.Cm(4.27),util.Cm(13.3),util.Cm(8),util.Cm(1.28))

cre_text(text_5_5,
         '继续深造与专业相关度',
         1.5 ,
         font_2,
         18,
         False,
         color1, PP_ALIGN.LEFT)

# %%
shape_5_6=slide_5.shapes.add_picture(pic_path+'继续深造与专业相关度.png',util.Cm(9.56 ),util.Cm(14.06),util.Cm(9.29 ),util.Cm(6.97))

#继续深造与专业相关度图标

#添加小图标
add_dylxt_icon(slide_5,4.68  ,15.41,0.88,0.6,color1)
add_dylxt_icon(slide_5,4.68  ,16.35 ,0.88,0.6,color2)
add_dylxt_icon(slide_5,4.68  ,17.26 ,0.88,0.6,color3)
add_dylxt_icon(slide_5,4.68  ,18.31,0.88,0.6,color4)
add_dylxt_icon(slide_5,4.68  ,19.2 ,0.88,0.6,color5)

text_5_6_1=slide_5.shapes.add_textbox(util.Cm(6.17 ),util.Cm(15.23),util.Cm(5),util.Cm(0.77 ))
text_5_6_2=slide_5.shapes.add_textbox(util.Cm(6.17),util.Cm(16.17),util.Cm(5),util.Cm( 0.77 ))
text_5_6_3=slide_5.shapes.add_textbox(util.Cm(6.17),util.Cm(17.08),util.Cm(5),util.Cm( 0.77 ))
text_5_6_4=slide_5.shapes.add_textbox(util.Cm(6.17),util.Cm(18.13),util.Cm(5),util.Cm( 0.77 ))
text_5_6_5=slide_5.shapes.add_textbox(util.Cm(6.17),util.Cm(19.02),util.Cm(5),util.Cm( 0.77 ))


zyxgd_index_list=[text_5_6_1,text_5_6_2,text_5_6_3,text_5_6_4,text_5_6_5]
zyxgd_list=["非常相关",'相关','比较相关','不相关','不太相关']
colorbox=[color1,color2,color3,color4,color5]
for i in range(5):
    cre_text(zyxgd_index_list[i],
         zyxgd_list[i],
         1.5 ,
         font_2,
         12,
         False,
         colorbox[i],
         PP_ALIGN.LEFT)

# %%
#升学院校类型Top3 
shape_5_7=slide_5.shapes.add_picture(pic_path+'黄色小梯形.png',util.Cm(2.56),util.Cm(20.7),util.Cm(2.64),util.Cm(2.64))

#添加文本框
text_5_7=slide_5.shapes.add_textbox(util.Cm(4.27),util.Cm(21.62),util.Cm(8),util.Cm(1.28))

cre_text(text_5_7,
         '升学院校类型Top3 ',
         1.5 ,
         font_2,
         18,
         False,
         color1, PP_ALIGN.LEFT)

# %%
shape_5_8_1=slide_5.shapes.add_picture(pic_path+'升学院校类型1.png',util.Cm(1.11),util.Cm(21.55 ),util.Cm(8.18),util.Cm(6.2))
shape_5_8_2=slide_5.shapes.add_picture(pic_path+'升学院校类型2.png',util.Cm(6.38),util.Cm(21.55 ),util.Cm(8.18),util.Cm(6.2))
shape_5_8_3=slide_5.shapes.add_picture(pic_path+'升学院校类型3.png',util.Cm(11.7 ),util.Cm(21.55 ),util.Cm(8.18),util.Cm(6.2))


text_5_9_1=slide_5.shapes.add_textbox(util.Cm(2.7),util.Cm(26.17 ),util.Cm(5),util.Cm(1.28))
text_5_9_2=slide_5.shapes.add_textbox(util.Cm(7.91),util.Cm(26.17 ),util.Cm(5),util.Cm(1.28))
text_5_9_3=slide_5.shapes.add_textbox(util.Cm(13.3),util.Cm(26.17 ),util.Cm(5),util.Cm(1.28))
text_5_9_4=slide_5.shapes.add_textbox(util.Cm(2.7),util.Cm(27.5),util.Cm(5),util.Cm(0.73))
text_5_9_5=slide_5.shapes.add_textbox(util.Cm(7.91),util.Cm(27.5),util.Cm(5),util.Cm(0.73))
text_5_9_6=slide_5.shapes.add_textbox(util.Cm(13.3),util.Cm(27.5),util.Cm(5),util.Cm(0.73))


#升学院校类型
sxlx_content_name=[
f'{sxlx_fir_number}人',
f'{sxlx_sec_number}人',
f'{sxlx_thi_number}人',
sxlx_fir_name,
sxlx_sec_name,
sxlx_thi_name
]
sxlx_text_name=[text_5_9_1,text_5_9_2,text_5_9_3,text_5_9_4,text_5_9_5,text_5_9_6]
#先写如数字，再写入汉字那行，这里比较特殊，
color_box=[color1,color4,color3,color1,color4,color3]
for i in range(3):
    cre_text(sxlx_text_name[i],
         sxlx_content_name[i],
         1.5 ,
         font_3,
         24,
         False,
         color_box[i], PP_ALIGN.CENTER) 
    
for j in range(3,6):
    cre_text(sxlx_text_name[j],
         sxlx_content_name[j],
         1.5 ,
         font_3,
         10,
         False,
         color_box[j], PP_ALIGN.CENTER)

# %% [markdown]
# # 开始第六页

# %%
#插入一个模板  其中六号模板是默认的空板式
slide_6 = prs.slides.add_slide(prs.slide_layouts[6])
#left top 用来定义位置，width,high确定大小

# %%
#标题6
shape_6_1=slide_6.shapes.add_picture(pic_path+'标题6.png',util.Cm(2.43),util.Cm(2.25),util.Cm(16.13),util.Cm(4.35))

# %%
#就业质量四个小图
shape_6_2_1=slide_6.shapes.add_picture(pic_path+'就业满意度.png',util.Cm(3.2181),util.Cm(5.3),util.Cm(2.31),util.Cm(2.31))
shape_6_2_2=slide_6.shapes.add_picture(pic_path+'就业专业相关度.png',util.Cm(7.2),util.Cm(5.3),util.Cm(2.31),util.Cm(2.31))
shape_6_2_3=slide_6.shapes.add_picture(pic_path+'职业期待匹配度.png',util.Cm(11.34),util.Cm(5.3),util.Cm(2.31),util.Cm(2.31))
shape_6_2_4=slide_6.shapes.add_picture(pic_path+'就业稳定性.png',util.Cm(15.28),util.Cm(5.3),util.Cm(2.31),util.Cm(2.31))

#就业质量四个小图内容
text_6_3_1=slide_6.shapes.add_textbox(util.Cm(3.26),util.Cm(8.18),util.Cm(4),util.Cm(0.9))
text_6_3_2=slide_6.shapes.add_textbox(util.Cm(3.16),util.Cm(8.84),util.Cm(4),util.Cm(1.22 ))
text_6_3_3=slide_6.shapes.add_textbox(util.Cm(6.87),util.Cm(8.16),util.Cm(5),util.Cm(0.9))
text_6_3_4=slide_6.shapes.add_textbox(util.Cm(7.23),util.Cm(8.84),util.Cm(4),util.Cm(1.22 ))
text_6_3_5=slide_6.shapes.add_textbox(util.Cm(10.93),util.Cm(8.16),util.Cm(5),util.Cm(0.9))
text_6_3_6=slide_6.shapes.add_textbox(util.Cm(11.29),util.Cm(8.84),util.Cm(4),util.Cm(1.22 ))
text_6_3_7=slide_6.shapes.add_textbox(util.Cm(15.44),util.Cm(8.16),util.Cm(4),util.Cm(0.9))
text_6_3_8=slide_6.shapes.add_textbox(util.Cm(15.35),util.Cm(8.84),util.Cm(4),util.Cm(1.22 ))
#就业质量四图信息
jyzl_content_name=['就业满意度',decimal(jymyd_ratio),'就业专业相关度',decimal(jyzyxgd_ratio),'职业期待匹配度',decimal(zyqdppd_ratio),'就业稳定性',decimal(jywdx_ratio)]
jyzl_text_name=[text_6_3_1,text_6_3_2,text_6_3_3,text_6_3_4,text_6_3_5,text_6_3_6,text_6_3_7,text_6_3_8]

#就业满意度部分
cre_text(jyzl_text_name[0],
     jyzl_content_name[0],
     1.5 ,
     font_3,
     12,
     False,
     RGBColor(241,170,64), PP_ALIGN.LEFT)#黄色
cre_text(jyzl_text_name[1],
     jyzl_content_name[1],
     1.5 ,
     font_1,
     18,
     False,
     RGBColor(241,170,64), PP_ALIGN.LEFT)#黄色

#就业专业相关度
cre_text(jyzl_text_name[2],
     jyzl_content_name[2],
     1.5 ,
     font_3,
     12,
     False,
     color1, PP_ALIGN.LEFT)#深蓝
cre_text(jyzl_text_name[3],
     jyzl_content_name[3],
     1.5 ,
     font_1,
     18,
     False,
     color1, PP_ALIGN.LEFT)#深蓝

#职业期待匹配度
cre_text(jyzl_text_name[4],
     jyzl_content_name[4],
     1.5 ,
     font_3,
     12,
     False,
     RGBColor(110,166,71), PP_ALIGN.LEFT)#红色
cre_text(jyzl_text_name[5],
     jyzl_content_name[5],
     1.5 ,
     font_1,
     18,
     False,
     RGBColor(110,166,71), PP_ALIGN.LEFT)#红色

#就业稳定性
cre_text(jyzl_text_name[6],
     jyzl_content_name[6],
     1.5 ,
     font_3,
     12,
     False,
     RGBColor(216,117,135), PP_ALIGN.LEFT)#浅蓝
cre_text(jyzl_text_name[7],
     jyzl_content_name[7],
     1.5 ,
     font_1,
     18,
     False,
     RGBColor(216,117,135), PP_ALIGN.LEFT)#浅蓝

# %%
#标题7
shape_6_4=slide_6.shapes.add_picture(pic_path+'标题7.png',util.Cm(2.48),util.Cm(10.86),util.Cm(16.15),util.Cm(4.35))

# %%
shape_6_5=slide_6.shapes.add_picture(pic_path+'教育教学反馈图.png',util.Cm(7.9),util.Cm(13.4),util.Cm(5.19),util.Cm(5.16))

# %%
# #教育教学四个小图内容
# text_6_6_1=slide_6.shapes.add_textbox(util.Cm(8.06),util.Cm(13.82),util.Cm(2.46),util.Cm(1.67))
# text_6_6_2=slide_6.shapes.add_textbox(util.Cm(4.02 ),util.Cm(13.84),util.Cm(5),util.Cm(1.63))
# text_6_6_3=slide_6.shapes.add_textbox(util.Cm(10.8),util.Cm(14.2),util.Cm(2.64),util.Cm(0.9))
# text_6_6_4=slide_6.shapes.add_textbox(util.Cm(13.77),util.Cm(13.84 ),util.Cm(5),util.Cm(1.63))
# text_6_6_5=slide_6.shapes.add_textbox(util.Cm(8.04),util.Cm(16.49),util.Cm(2.43),util.Cm(1.67))
# text_6_6_6=slide_6.shapes.add_textbox(util.Cm(4.02 ),util.Cm(16.51),util.Cm(5),util.Cm(1.63))
# text_6_6_7=slide_6.shapes.add_textbox(util.Cm(10.73),util.Cm(16.49 ),util.Cm(2.3),util.Cm(1.67))
# text_6_6_8=slide_6.shapes.add_textbox(util.Cm(13.78),util.Cm(16.51),util.Cm(5),util.Cm(1.63))
# #教育教学四图信息
# #云就业调研：教育教学满意度，湖南省中心调研：实践教学满意度
# # jyzl_content_name=['母校人才培养满意度',decimal(rcpymyd_ratio),'母校推荐度',decimal(mxtjd_ratio),'教育教学满意度',decimal(jyjxmyd_ratio),'就业创业服务满意度',decimal(jycyfwmyd_ratio)]
# # jyzl_text_name=[text_6_6_1,text_6_6_2,text_6_6_3,text_6_6_4,text_6_6_5,text_6_6_6,text_6_6_7,text_6_6_8]
# # jyzl_content_name[0] =jyzl_content_name[0].replace(',', '')
# # jyzl_content_name[1] =jyzl_content_name[1].replace(',', '')
# # jyzl_content_name[2] =jyzl_content_name[2].replace(',', '')
# # jyzl_content_name[3] =jyzl_content_name[3].replace(',', '')
# # jyzl_content_name[4] =jyzl_content_name[4].replace(',', '')
# # jyzl_content_name[5] =jyzl_content_name[5].replace(',', '')
# # jyzl_content_name[6] =jyzl_content_name[6].replace(',', '')

# # jyzl_text_name[0] =jyzl_text_name[0].replace(',', '')
# # jyzl_text_name[1] =jyzl_text_name[1].replace(',', '')
# # jyzl_text_name[2] =jyzl_text_name[2].replace(',', '')
# # jyzl_text_name[3] =jyzl_text_name[3].replace(',', '')
# # jyzl_text_name[4] =jyzl_text_name[4].replace(',', '')
# # jyzl_text_name[5] =jyzl_text_name[5].replace(',', '')
# # jyzl_text_name[6] =jyzl_text_name[6].replace(',', '')

# # jyzl_content_name[4] =jyzl_content_name[4].replace(',', '')
# #母校人才培养满意度
# cre_text(text_6_6_1,
#     '母校人才培养满意度',
#      1.5 ,
#      '思源黑体 CN Regular',
#      12,
#      False,
#      RGBColor(255,255,255), PP_ALIGN.LEFT)
# cre_text(text_6_6_2,
#      decimal(rcpymyd_ratio),
#      1.5 ,
#      '思源黑体 CN Heavy',
#      24,
#      False,
#      color1, PP_ALIGN.LEFT)#深蓝

# #母校推荐度
# cre_text(text_6_6_3,
#      '母校推荐度',
#      1.5 ,
#      '思源黑体 CN Regular',
#      12,
#      False,
#      RGBColor(255,255,255), PP_ALIGN.LEFT)
# cre_text(text_6_6_4,
#      decimal(mxtjd_ratio),
#      1.5 ,
#      '思源黑体 CN Heavy',
#      24,
#      False,
#      RGBColor(241,170,64), PP_ALIGN.LEFT)#黄色

# #教育教学满意度
# cre_text(text_6_6_5,
#      '实践教学满意度',
#      1.5 ,
#      '思源黑体 CN Regular',
#      12,
#      False,
#      RGBColor(255,255,255), PP_ALIGN.LEFT)
# cre_text(text_6_6_6,
#     decimal(jyjxmyd_ratio),
#      1.5 ,
#      '思源黑体 CN Heavy',
#      24,
#      False,
#      RGBColor(216,117,135), PP_ALIGN.LEFT)#红色

# #就业创业服务满意度
# cre_text(text_6_6_7,
#      '就业创业服务满意度',
#      1.5 ,
#      '思源黑体 CN Regular',
#      12,
#      False,
#      RGBColor(255,255,255), PP_ALIGN.LEFT)
# cre_text(text_6_6_8,
#      '98.19%',
#      1.5 ,
#      '思源黑体 CN Heavy',
#      24,
#      False,
#      RGBColor(47,151,195), PP_ALIGN.LEFT)#浅蓝

# %%
#教育教学四个小图内容
text_6_6_1=slide_6.shapes.add_textbox(util.Cm(8.06),util.Cm(13.82),util.Cm(2.46),util.Cm(1.67))
text_6_6_2=slide_6.shapes.add_textbox(util.Cm(4.02 ),util.Cm(13.84),util.Cm(5),util.Cm(1.63))
text_6_6_3=slide_6.shapes.add_textbox(util.Cm(10.8),util.Cm(14.2),util.Cm(2.64),util.Cm(0.9))
text_6_6_4=slide_6.shapes.add_textbox(util.Cm(13.77),util.Cm(13.84 ),util.Cm(5),util.Cm(1.63))
text_6_6_5=slide_6.shapes.add_textbox(util.Cm(8.04),util.Cm(16.49),util.Cm(2.43),util.Cm(1.67))
text_6_6_6=slide_6.shapes.add_textbox(util.Cm(4.02 ),util.Cm(16.51),util.Cm(5),util.Cm(1.63))
text_6_6_7=slide_6.shapes.add_textbox(util.Cm(10.73),util.Cm(16.49 ),util.Cm(2.3),util.Cm(1.67))
text_6_6_8=slide_6.shapes.add_textbox(util.Cm(13.78),util.Cm(16.51),util.Cm(5),util.Cm(1.63))

#教育教学四图信息
#云就业调研：教育教学满意度，湖南省中心调研：实践教学满意度
jyzl_content_name=['母校人才培养满意度',decimal(rcpymyd_ratio),'母校推荐度',decimal(mxtjd_ratio),'教育教学满意度',decimal(jyjxmyd_ratio),'就业创业服务满意度',decimal(jycyfwmyd_ratio)]
jyzl_text_name=[text_6_6_1,text_6_6_2,text_6_6_3,text_6_6_4,text_6_6_5,text_6_6_6,text_6_6_7,text_6_6_8]

#母校人才培养满意度
cre_text(jyzl_text_name[0],
     jyzl_content_name[0],
     1.5 ,
     font_3,
     12,
     False,
     RGBColor(255,255,255), PP_ALIGN.LEFT)
cre_text(jyzl_text_name[1],
     jyzl_content_name[1],
     1.5 ,
     font_1,
     24,
     False,
     color1, PP_ALIGN.LEFT)#深蓝

#母校推荐度
cre_text(jyzl_text_name[2],
     jyzl_content_name[2],
     1.5 ,
     font_3,
     12,
     False,
     RGBColor(255,255,255), PP_ALIGN.LEFT)
cre_text(jyzl_text_name[3],
     jyzl_content_name[3],
     1.5 ,
     font_1,
     24,
     False,
     RGBColor(241,170,64), PP_ALIGN.LEFT)#黄色

#教育教学满意度
cre_text(jyzl_text_name[4],
     jyzl_content_name[4],
     1.5 ,
     font_3,
     12,
     False,
     RGBColor(255,255,255), PP_ALIGN.LEFT)
cre_text(jyzl_text_name[5],
     jyzl_content_name[5],
     1.5 ,
     font_1,
     24,
     False,
     RGBColor(109,166,71), PP_ALIGN.LEFT)#红色

#就业创业服务满意度
cre_text(jyzl_text_name[6],
     jyzl_content_name[6],
     1.5 ,
     font_3,
     12,
     False,
     RGBColor(255,255,255), PP_ALIGN.LEFT)
cre_text(jyzl_text_name[7],
     jyzl_content_name[7],
     1.5 ,
     font_1,
     24,
     False,
     RGBColor(230,113,135), PP_ALIGN.LEFT)#浅蓝

# %%
#标题8
shape_6_7=slide_6.shapes.add_picture(pic_path+'标题8.png',util.Cm(2.43),util.Cm(19.26),util.Cm(16.13 ),util.Cm(4.35))

# %%
#社会评价图
shape_6_8_1=slide_6.shapes.add_picture(pic_path+'用人单位对毕业生满意度.png',util.Cm(1.54 ),util.Cm(21.53),util.Cm(6.5),util.Cm(4.91))
shape_6_8_2=slide_6.shapes.add_picture(pic_path+'用人单位对人才培养满意度.png',util.Cm(7.28 ),util.Cm(21.53),util.Cm(6.5),util.Cm(4.91))
shape_6_8_3=slide_6.shapes.add_picture(pic_path+'用人单位对就业服务培养满意度.png',util.Cm(12.93),util.Cm(21.53),util.Cm(6.5),util.Cm(4.91))


text_6_9_1=slide_6.shapes.add_textbox(util.Cm(3.27),util.Cm(23.29),util.Cm(3),util.Cm(1.15))
text_6_9_2=slide_6.shapes.add_textbox(util.Cm(8.92),util.Cm(23.29),util.Cm(3),util.Cm(1.15))
text_6_9_3=slide_6.shapes.add_textbox(util.Cm(14.81),util.Cm(23.29),util.Cm(3),util.Cm(1.15))

text_6_9_4=slide_6.shapes.add_textbox(util.Cm(2.91 ),util.Cm(26.62),util.Cm(4),util.Cm(1.28))
text_6_9_5=slide_6.shapes.add_textbox(util.Cm(8.35),util.Cm(26.62),util.Cm(4),util.Cm(1.28))
text_6_9_6=slide_6.shapes.add_textbox(util.Cm(14.17),util.Cm(26.62),util.Cm(4),util.Cm(1.28))


shpj_content_name=[decimal(cdy_bysmyd_ratio),decimal(0.9927),decimal(cdy_jyfwmyd_ratio),'用人单位对毕业生满意度','用人单位对学校人才培养满意度','用人单位对就业服务满意度']
shpj_text_name=[text_6_9_1,text_6_9_2,text_6_9_3,text_6_9_4,text_6_9_5,text_6_9_6]


color_box=[color1,color4,color3,color1,color4,color3]
for i in range(3):
    cre_text(shpj_text_name[i],
         shpj_content_name[i],
         1.5 ,
         font_3,
         20,
         False,
         color_box[i], PP_ALIGN.CENTER) 
    
for j in range(3,6):
    cre_text(shpj_text_name[j],
         shpj_content_name[j],
         1.5 ,
         font_3,
         12,
         False,
         color_box[j], PP_ALIGN.CENTER)

# %%
prs.save(pic_path+'微报告.pptx')
